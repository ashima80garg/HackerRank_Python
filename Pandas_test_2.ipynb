# %% [markdown]
# <a href="https://colab.research.google.com/github/ashima80garg/HackerRank_Python/blob/main/Pandas_test_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step1: Import the necessary libraries
import pandas as pd

# %%
# Step 2 and 3: Import the dataset and assign it to a variable named chipo
chipo=pd.read_table("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv")

# %%
# Step 4: See first 10 entries
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
# Step 5: What are the number of observations in the dataset
len(chipo)
# Out:
# 4622

# %%
# Step 6: What are the number of columns in the dataset
len(chipo.columns)
# Out:
# 5

# %%
# Step 7: Print the names of all the columns
list(chipo.columns)
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %%
# Step 8: How is the dataset indexed
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# Step 9: which is the most ordered item
df=chipo.groupby("order_id").quantity.sum().sort_values(ascending=False)
df
# Out:
# order_id
# 1443    35
# 926     23
# 1786    20
# 1660    19
# 759     18
#         ..
# 819      1
# 821      1
# 107      1
# 1311     1
# 72       1
# Name: quantity, Length: 1834, dtype: int64

# %%
df=pd.DataFrame(df)
df
# Out:
#           quantity
# order_id
# 1443            35
# 926             23
# 1786            20
# 1660            19
# 759             18
# ...            ...
# 819              1
# 821              1
# 107              1
# 1311             1
# 72               1
#
# [1834 rows x 1 columns]

# %%
l=list(df.index)
print("most ordered item is having order id=",l[0])
# Out:
# most ordered item is having order id= 1443

# %%
# can not find name as there are many items for this id
chipo[chipo.order_id==1443]
# Out:
#       order_id  quantity                     item_name  \
# 3598      1443        15  Chips and Fresh Tomato Salsa
# 3599      1443         7                 Bottled Water
# 3600      1443         1             6 Pack Soft Drink
# 3601      1443         3                Veggie Burrito
# 3602      1443         4               Chicken Burrito
# 3603      1443         3                 Steak Burrito
# 3604      1443         2                 Bottled Water
#
#                                      choice_description item_price
# 3598                                                NaN    $44.25
# 3599                                                NaN    $10.50
# 3600                                             [Coke]     $6.49
# 3601  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $33.75
# 3602  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $35.00
# 3603  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    $27.75
# ...

# %%
# Step 10: For the most ordered item, how many items were ordered?

q=df.iloc[0]
print("the quantity is=",q)
# Out:
# the quantity is= quantity    35
# Name: 1443, dtype: int64

# %%
# Step 11: what was the most ordered item in choice description column?

chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df=chipo.choice_description.value_counts()
df
# Out:
# [Diet Coke]                                                                                                                                      134
# [Coke]                                                                                                                                           123
# [Sprite]                                                                                                                                          77
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]                                                                            42
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                                                 40
#                                                                                                                                                 ...
# ...

# %%
item=df.head(1).index
a=list(item)
print("most ordered item is",a)
# Out:
# most ordered item is ['[Diet Coke]']

# %%
# for the most ordered item how many items were ordered
print("the most ordered item:",df[0])
# Out:
# the most ordered item: 134

# %%
# Step 12: How many items were ordered in total?

df=chipo.groupby("order_id").quantity.sum().sort_values()
df
# Out:
# order_id
# 917      1
# 819      1
# 821      1
# 512      1
# 1273     1
#         ..
# 759     18
# 1660    19
# 1786    20
# 926     23
# 1443    35
# Name: quantity, Length: 1834, dtype: int64

# %%
n=len(df)
print("total number of items ordered:",n)
# Out:
# total number of items ordered: 1043

# %%
# Step 13: Turn item price into float

#Step 13a: Check the type
chipo.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
chipo["item_price"]=chipo.item_price.str.replace("$","")
chipo.head()
# Out:
# <ipython-input-43-aa94923d3a77>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   chipo["item_price"]=chipo.item_price.str.replace("$","")
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN      2.39
# 1                                       [Clementine]      3.39
# 2                                            [Apple]      3.39
# ...

# %%
chipo.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
chipo["item_price"]=chipo.item_price.astype("float")
chipo.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
# Step 14: How much was the revenue
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
revenue=chipo.item_price.sum()
revenue
# Out:
# 34500.16

# %%
# Step 15: How many orders were made?

orders=chipo.quantity.sum()
orders
# Out:
# 4972

# %%
# Step 16: Average revenue amount per order

df=chipo.groupby("order_id").item_price.mean()
df
# Out:
# order_id
# 1        2.890000
# 2       16.980000
# 3        6.335000
# 4       10.500000
# 5        6.850000
#           ...
# 1830    11.500000
# 1831     4.300000
# 1832     6.600000
# 1833    11.750000
# 1834     9.583333
# Name: item_price, Length: 1834, dtype: float64

# %%
# Step 17: How many different items were sold?

len(df)
# Out:
# 1834
