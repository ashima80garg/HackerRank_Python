# %% [markdown]
# <a href="https://colab.research.google.com/github/ashima80garg/HackerRank_Python/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# **2: Reading a file by giving its path**

# %%
pd.read_csv("/content/chipotle.tsv",sep="\t")  # data is tab seperated, if u use read_csv then specify seperator if other than comma

                                                # Alternate way: read_table assumes that the data is tab seperated
# pd.read_table("/content/chipotle.tsv")
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df=pd.read_table("/content/chipotle.tsv")

# %%
print(df.head())
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
#pd.read_table("/content/u.user")  # seperated by | seperator, default is tab
pd.read_csv("/content/u.user")    # same output as csv assumes commas, table assumes tab, if any other format, use sep
# Out:
#           1|24|M|technician|85711
# 0              2|53|F|other|94043
# 1             3|23|M|writer|32067
# 2         4|24|M|technician|43537
# 3              5|33|F|other|15213
# 4          6|42|M|executive|98101
# ..                            ...
# 937        939|26|F|student|33319
# 938  940|32|M|administrator|02215
# 939        941|20|M|student|97229
# 940      942|48|F|librarian|78209
# 941        943|22|M|student|77841
#
# [942 rows x 1 columns]

# %%
pd.read_table("/content/u.user", sep="|")  # first row is not the heading
# Out:
#        1  24  M     technician  85711
# 0      2  53  F          other  94043
# 1      3  23  M         writer  32067
# 2      4  24  M     technician  43537
# 3      5  33  F          other  15213
# 4      6  42  M      executive  98101
# ..   ...  .. ..            ...    ...
# 937  939  26  F        student  33319
# 938  940  32  M  administrator  02215
# 939  941  20  M        student  97229
# 940  942  48  F      librarian  78209
# 941  943  22  M        student  77841
#
# [942 rows x 5 columns]

# %%
# The dataset is not having column names, so it is displaying first row as column name
# to avoid this,write header=None, it will provide numbers to the headings

pd.read_table("/content/u.user", sep="|", header=None)
# Out:
#        0   1  2              3      4
# 0      1  24  M     technician  85711
# 1      2  53  F          other  94043
# 2      3  23  M         writer  32067
# 3      4  24  M     technician  43537
# 4      5  33  F          other  15213
# ..   ...  .. ..            ...    ...
# 938  939  26  F        student  33319
# 939  940  32  M  administrator  02215
# 940  941  20  M        student  97229
# 941  942  48  F      librarian  78209
# 942  943  22  M        student  77841
#
# [943 rows x 5 columns]

# %%
heading=["userid","age","gender","occupation","zip_code"]
pd.read_csv("/content/u.user", sep="|", header=None, names=heading)   # for providing user defined attribute names
# Out:
#      userid  age gender     occupation zip_code
# 0         1   24      M     technician    85711
# 1         2   53      F          other    94043
# 2         3   23      M         writer    32067
# 3         4   24      M     technician    43537
# 4         5   33      F          other    15213
# ..      ...  ...    ...            ...      ...
# 938     939   26      F        student    33319
# 939     940   32      M  administrator    02215
# 940     941   20      M        student    97229
# 941     942   48      F      librarian    78209
# 942     943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
df=pd.read_table("/content/u.user", sep="|", header=None, names=heading) # update the data frame object

# %%
print(df.head())
# Out:
#    userid  age gender  occupation zip_code
# 0       1   24      M  technician    85711
# 1       2   53      F       other    94043
# 2       3   23      M      writer    32067
# 3       4   24      M  technician    43537
# 4       5   33      F       other    15213

# %%
df.head()
# Out:
#    userid  age gender  occupation zip_code
# 0       1   24      M  technician    85711
# 1       2   53      F       other    94043
# 2       3   23      M      writer    32067
# 3       4   24      M  technician    43537
# 4       5   33      F       other    15213

# %% [markdown]
# video 1: Summary:
#
# 1. use pd.read_csv or pd.read_table. If the data is in assumed format then fine, if other seperator is there, specify that using sep. Both will have same output.
#
# 2. header attribute: None means headings not available in the dataset, so python will provide numbers.
#
# 3. names attribute: provide some value or list specifying attribute names.

# %% [markdown]
# **3: Selecting a pandas Series from a DataFrame?**

# %%
import pandas as pd

# %%
df1=pd.read_csv("/content/ufo.csv")  # created new df object from a csv file

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df1["City"]  # selects city series
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
#                  ...
# 18236              Grant Park
# 18237             Spirit Lake
# 18238             Eagle River
# 18239             Eagle River
# 18240                    Ybor
# Name: City, Length: 18241, dtype: object

# %%
type(df1['City'])  # Complete table is dataframe while attributes are series
# Out:
# pandas.core.series.Series

# %%
df1.City  # dot notation can also be used
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
#                  ...
# 18236              Grant Park
# 18237             Spirit Lake
# 18238             Eagle River
# 18239             Eagle River
# 18240                    Ybor
# Name: City, Length: 18241, dtype: object

# %%
type(df1.City)
# Out:
# pandas.core.series.Series

# %%
# df1.Colors Reported     # dot representation does not work when attribute name has space, use brackets

df1["Colors Reported"]    # dot notattion does not always work, but it is faster to type
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 18236    NaN
# 18237    NaN
# 18238    NaN
# 18239    RED
# 18240    NaN
# Name: Colors Reported, Length: 18241, dtype: object

# %%
# in case of name conflict of an attribute with an existing method, then method will be considered

df1.shape   # error with shape() if shape as an attribute as well, then python will take it as method access
# Out:
# (18241, 5)

# %%
# Create a new series in dataframe
# When assigning use dot notation

df1.City+df1.State                     # appends all individual values
df1.Location=df1.City+","+df1.State    # dot notation wont work while creating new series
df1.head()
# Out:
# <ipython-input-10-12558a2c6783>:5: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df1.Location=df1.City+","+df1.State  # dot notation wont work while creating new series
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df1.City+df1.State                      # appends all individual values
df1["Location"]=df1.City+","+df1.State  # dot notation wont work while creating new attribute
df1.head()
# Out:
#                    City Colors Reported Shape Reported State             Time  \
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
#
#                   Location
# 0                Ithaca,NY
# 1           Willingboro,NJ
# 2               Holyoke,CO
# 3               Abilene,KS
# 4  New York Worlds Fair,NY

# %%
df1.State=df1.City+","+df1.State  # dot representation would work while updating existing attribute
df1.head()
# Out:
#                    City Colors Reported Shape Reported  \
# 0                Ithaca             NaN       TRIANGLE
# 1           Willingboro             NaN          OTHER
# 2               Holyoke             NaN           OVAL
# 3               Abilene             NaN           DISK
# 4  New York Worlds Fair             NaN          LIGHT
#
#                      State             Time
# 0                Ithaca,NY   6/1/1930 22:00
# 1           Willingboro,NJ  6/30/1930 20:00
# 2               Holyoke,CO  2/15/1931 14:00
# 3               Abilene,KS   6/1/1931 13:00
# 4  New York Worlds Fair,NY  4/18/1933 19:00

# %% [markdown]
# **4: Some pandas commands end with parentheses and others don't?**

# %%
df3=pd.read_csv("/content/imdb_1000.csv")
df3.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df3.describe()  # stats of all numeric attributes
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
df3.shape
# Out:
# (979, 6)

# %%
df3.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
# Attributes describe object: height, weight
# Method are actions to be taken: talk(), eat()

# %%
# Only describe attribute of type int64
df3.describe(include=['int'])  # some methods can have optional arguments (functions)
# Out:
#          duration
# count  979.000000
# mean   120.979571
# std     26.218010
# min     64.000000
# 25%    102.000000
# 50%    117.000000
# 75%    134.000000
# max    242.000000

# %% [markdown]
# **5: Renaming columns in a pandas DataFrame**

# %%
df4=pd.read_csv("/content/ufo.csv")

# %%
df4.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df4.columns # returns list of column names
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
df4.rename(columns={'Colors Reported':'Colors'})  # dictionay to rename column name
# Out:
#                        City Colors Shape Reported State              Time
# 0                    Ithaca    NaN       TRIANGLE    NY    6/1/1930 22:00
# 1               Willingboro    NaN          OTHER    NJ   6/30/1930 20:00
# 2                   Holyoke    NaN           OVAL    CO   2/15/1931 14:00
# 3                   Abilene    NaN           DISK    KS    6/1/1931 13:00
# 4      New York Worlds Fair    NaN          LIGHT    NY   4/18/1933 19:00
# ...                     ...    ...            ...   ...               ...
# 18236            Grant Park    NaN       TRIANGLE    IL  12/31/2000 23:00
# 18237           Spirit Lake    NaN           DISK    IA  12/31/2000 23:00
# 18238           Eagle River    NaN            NaN    WI  12/31/2000 23:45
# 18239           Eagle River    RED          LIGHT    WI  12/31/2000 23:45
# 18240                  Ybor    NaN           OVAL    FL  12/31/2000 23:59
#
# [18241 rows x 5 columns]

# %%
df4.columns=['col1','col2','col3','col4','col5']  # rename all the columns

# %%
df4.columns
# Out:
# Index(['col1', 'col2', 'col3', 'col4', 'col5'], dtype='object')

# %%
# rename columns while reading the file

headings=['c1','c2','c3','c4','c5']
df4=pd.read_csv("/content/ufo.csv", names=headings)
df4.head()
# Out:
#             c1               c2              c3     c4               c5
# 0         City  Colors Reported  Shape Reported  State             Time
# 1       Ithaca              NaN        TRIANGLE     NY   6/1/1930 22:00
# 2  Willingboro              NaN           OTHER     NJ  6/30/1930 20:00
# 3      Holyoke              NaN            OVAL     CO  2/15/1931 14:00
# 4      Abilene              NaN            DISK     KS   6/1/1931 13:00

# %%
# if there are 100 attributes replace 'c' with 'd'

df4.columns=df4.columns.str.replace("c","d")  #series_name.str.str_method
df4.head()
# Out:
#             d1               d2              d3     d4               d5
# 0         City  Colors Reported  Shape Reported  State             Time
# 1       Ithaca              NaN        TRIANGLE     NY   6/1/1930 22:00
# 2  Willingboro              NaN           OTHER     NJ  6/30/1930 20:00
# 3      Holyoke              NaN            OVAL     CO  2/15/1931 14:00
# 4      Abilene              NaN            DISK     KS   6/1/1931 13:00

# %% [markdown]
# **6: Removing columns from a pandas DataFrame**

# %%
df5=pd.read_csv("/content/ufo.csv")
df5.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
a=df5.drop("City",axis=1)
a.head()
# Out:
#   Colors Reported Shape Reported State             Time
# 0             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1             NaN          OTHER    NJ  6/30/1930 20:00
# 2             NaN           OVAL    CO  2/15/1931 14:00
# 3             NaN           DISK    KS   6/1/1931 13:00
# 4             NaN          LIGHT    NY  4/18/1933 19:00

# %%
a=df5.drop(['State',"Time"],axis=1) # drop multiple columns
a.head()
# Out:
#                    City Colors Reported Shape Reported
# 0                Ithaca             NaN       TRIANGLE
# 1           Willingboro             NaN          OTHER
# 2               Holyoke             NaN           OVAL
# 3               Abilene             NaN           DISK
# 4  New York Worlds Fair             NaN          LIGHT

# %%
a=df5.drop(0, axis=0) # drops 1st row , row names are also called as index or labels
a.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
# 5           Valley City             NaN           DISK    ND  9/15/1934 15:30

# %%
a=df5.drop([0,1,2])  # by default axis=0
a.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00
# 5           Valley City             NaN           DISK    ND  9/15/1934 15:30
# 6           Crater Lake             NaN         CIRCLE    CA   6/15/1935 0:00
# 7                  Alma             NaN           DISK    MI   7/15/1936 0:00

# %%
# drop from 10th to 15th row??????????????????????????????????????????????????????????????????????????????
df_new=df5.drop(df.index[10:16])
df_new.head(20)

# %% [markdown]
# **7: Sorting a pandas DataFrame or a Series**

# %%
import pandas as pd
df6=pd.read_csv("/content/imdb_1000.csv")
df6.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
# sort according to title series

# Method1
#df6['title'].sort_values(ascending=False)

# Method2
df6.title.sort_values()
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
#                ...
# 955         Zero Dark Thirty
# 677                   Zodiac
# 615               Zombieland
# 526                     Zulu
# 864                    [Rec]
# Name: title, Length: 979, dtype: object

# %%
a=df6.sort_values("title",ascending=False)
a.head()
# Out:
#      star_rating             title content_rating   genre  duration  \
# 864          7.5             [Rec]              R  Horror        78
# 526          7.8              Zulu        UNRATED   Drama       138
# 615          7.7        Zombieland              R  Comedy        88
# 677          7.7            Zodiac              R   Crime       157
# 955          7.4  Zero Dark Thirty              R   Drama       157
#
#                                            actors_list
# 864  [u'Manuela Velasco', u'Ferran Terraza', u'Jorg...
# 526  [u'Stanley Baker', u'Jack Hawkins', u'Ulla Jac...
# 615  [u'Jesse Eisenberg', u'Emma Stone', u'Woody Ha...
# 677  [u'Jake Gyllenhaal', u'Robert Downey Jr.', u'M...
# 955  [u'Jessica Chastain', u'Joel Edgerton', u'Chri...

# %%
a=df6.sort_values(["star_rating","genre"],ascending=False)  # give inside list
a.tail()  # first sort acc. to star_rating and then genre
# Out:
#      star_rating                                            title  \
# 975          7.4                      Back to the Future Part III
# 954          7.4                                            X-Men
# 963          7.4                                  La Femme Nikita
# 967          7.4                                         The Rock
# 976          7.4  Master and Commander: The Far Side of the World
#
#     content_rating      genre  duration  \
# 975             PG  Adventure       118
# 954          PG-13     Action       104
# 963              R     Action       118
# 967              R     Action       136
# 976          PG-13     Action       138
#
#                                            actors_list
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 954  [u'Patrick Stewart', u'Hugh Jackman', u'Ian Mc...
# 963  [u'Anne Parillaud', u'Marc Duret', u'Patrick F...
# 967   [u'Sean Connery', u'Nicolas Cage', u'Ed Harris']
# ...

# %% [markdown]
# **8: Filtering rows by column values**

# %%
df7=pd.read_csv("/content/imdb_1000.csv")
df7.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
# create a list of booleans, convert into series

flag=[]
for i in df7.duration:
  if i>=200:
    flag.append(True)
  else:
    flag.append(False)

# %%
flag[:5]
# Out:
# [False, False, True, False, False]

# %%
len(flag)
# Out:
# 979

# %%
new=pd.Series(flag) # convert flag into series named new

# %%
new.head() # new is now a series
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %%
df7[new] # it shows only those rows having new to be true
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# ...

# %%
# Alternate way: without using for loop

criteria=df7.duration>=200  # creates a series without using for loop
df7[criteria].head()
# Out:
#     star_rating                                          title content_rating  \
# 2           9.1                         The Godfather: Part II              R
# 7           8.9  The Lord of the Rings: The Return of the King          PG-13
# 17          8.7                                  Seven Samurai        UNRATED
# 78          8.4                    Once Upon a Time in America              R
# 85          8.4                             Lawrence of Arabia             PG
#
#         genre  duration                                        actors_list
# 2       Crime       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 7   Adventure       201  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 17      Drama       207  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 78      Crime       229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 85  Adventure       216  [u"Peter O'Toole", u'Alec Guinness', u'Anthony...

# %%
# Even shorter

df7[df7.duration>=200].head()
  # the inner part is creating a series of booleans with the same length as that of the dataframe
  # outer part prints values only where value is true
# Out:
#     star_rating                                          title content_rating  \
# 2           9.1                         The Godfather: Part II              R
# 7           8.9  The Lord of the Rings: The Return of the King          PG-13
# 17          8.7                                  Seven Samurai        UNRATED
# 78          8.4                    Once Upon a Time in America              R
# 85          8.4                             Lawrence of Arabia             PG
#
#         genre  duration                                        actors_list
# 2       Crime       200  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 7   Adventure       201  [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 17      Drama       207  [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 78      Crime       229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 85  Adventure       216  [u"Peter O'Toole", u'Alec Guinness', u'Anthony...

# %%
df7[df7.duration>=200].genre   # previous outputs the complete dataframe, we want just the genre

# df7[df7.duration>=200][genre]
# Out:
# 2          Crime
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %%
# Another way:

df7.loc[df7.duration>=200,'genre']  # rows, col
# Out:
# 2          Crime
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %% [markdown]
# **9: Applying multiple filter criteria to a pandas DataFrame**

# %%
df8=pd.read_csv('/content/imdb_1000.csv')
df8.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df8[(df8.duration>=200) & (df8.genre=="Crime")]
# Out:
#     star_rating                        title content_rating  genre  duration  \
# 2           9.1       The Godfather: Part II              R  Crime       200
# 78          8.4  Once Upon a Time in America              R  Crime       229
#
#                                           actors_list
# 2   [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 78  [u'Robert De Niro', u'James Woods', u'Elizabet...

# %%
# df8[(df8.genre=="Drama") | (df8.genre=="Action") | (df8.genre=="Crime")]

# Another way for multiple OR conditions:
df8[df8.genre.isin (["Drama","Action","Crime"])]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 970          7.4                                      Wonder Boys
# 972          7.4                                   Blue Valentine
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %% [markdown]
# **10: Reading few columns or rows**

# %%
# read only few columns from csv file

df9=pd.read_csv("/content/ufo.csv")
df9.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
# read only city and time

df9=pd.read_csv("/content/ufo.csv",usecols=[0,4])
df9.head()
# Out:
#                    City             Time
# 0                Ithaca   6/1/1930 22:00
# 1           Willingboro  6/30/1930 20:00
# 2               Holyoke  2/15/1931 14:00
# 3               Abilene   6/1/1931 13:00
# 4  New York Worlds Fair  4/18/1933 19:00

# %%
df9=pd.read_csv("/content/ufo.csv",usecols=['City','Time'])
df9.head()
# Out:
#                    City             Time
# 0                Ithaca   6/1/1930 22:00
# 1           Willingboro  6/30/1930 20:00
# 2               Holyoke  2/15/1931 14:00
# 3               Abilene   6/1/1931 13:00
# 4  New York Worlds Fair  4/18/1933 19:00

# %%
# read only first 4 rows

df9=pd.read_csv("/content/ufo.csv", nrows=4)
df9
# Out:
#           City  Colors Reported Shape Reported State             Time
# 0       Ithaca              NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro              NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke              NaN           OVAL    CO  2/15/1931 14:00
# 3      Abilene              NaN           DISK    KS   6/1/1931 13:00

# %% [markdown]
# **11: "axis" parameter in pandas**

# %%
import pandas as pd

# %%
df10=pd.read_csv('/content/imdb_1000.csv')
df10.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df10.mean(axis=0)
# Out:
# <ipython-input-6-235ea80c5fa5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df10.mean(axis=0)
# star_rating      7.889785
# duration       120.979571
# dtype: float64

# %% [markdown]
# **12: Using string methods with attributes**

# %%
df11=pd.read_table("/content/chipotle.tsv")
df11.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df11.item_name.str.upper()  # first convert series into string and then use string methods
# Out:
# 0                CHIPS AND FRESH TOMATO SALSA
# 1                                        IZZE
# 2                            NANTUCKET NECTAR
# 3       CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4                                CHICKEN BOWL
#                         ...
# 4617                            STEAK BURRITO
# 4618                            STEAK BURRITO
# 4619                       CHICKEN SALAD BOWL
# 4620                       CHICKEN SALAD BOWL
# 4621                       CHICKEN SALAD BOWL
# Name: item_name, Length: 4622, dtype: object

# %% [markdown]
# **13: Changing the data type of a pandas Series**

# %%
df12=pd.read_table("/content/chipotle.tsv")
df12.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
df12.quantity=df12.quantity.astype(float)
df12.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1       1.0           Chips and Fresh Tomato Salsa
# 1         1       1.0                                   Izze
# 2         1       1.0                       Nantucket Nectar
# 3         1       1.0  Chips and Tomatillo-Green Chili Salsa
# 4         2       2.0                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# how to define data type before reading csv

df12=pd.read_table("/content/chipotle.tsv", dtype={'order_id':float})
df12.head()
# Out:
#    order_id  quantity                              item_name  \
# 0       1.0         1           Chips and Fresh Tomato Salsa
# 1       1.0         1                                   Izze
# 2       1.0         1                       Nantucket Nectar
# 3       1.0         1  Chips and Tomatillo-Green Chili Salsa
# 4       2.0         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
a=df12.item_price.str.replace("$","")
print(a.astype(float).mean())
# Out:
# 7.464335785374297
# <ipython-input-42-4548380af679>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   a=df12.item_price.str.replace("$","")

# %%
df12.item_name.str.contains("Chips").astype(int).head()  #can be used in ML features
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: item_name, dtype: int64

# %% [markdown]
# **14: Using "groupby" in pandas**

# %%
df3=pd.read_csv("/content/imdb_1000.csv")
df3.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df3.groupby("genre").mean().head()
# Out:
# <ipython-input-73-3d95f28b0a71>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3.groupby("genre").mean().head()
#            star_rating    duration
# genre
# Action        7.884559  126.485294
# Adventure     7.933333  134.840000
# Animation     7.914516   96.596774
# Biography     7.862338  131.844156
# Comedy        7.822436  107.602564

# %%
df3.groupby("genre").duration.mean()
# Out:
# genre
# Action       126.485294
# Adventure    134.840000
# Animation     96.596774
# Biography    131.844156
# Comedy       107.602564
# Crime        122.298387
# Drama        126.539568
# Family       107.500000
# Fantasy      112.000000
# Film-Noir     97.333333
# History       66.000000
# Horror       102.517241
# Mystery      115.625000
# Sci-Fi       109.000000
# Thriller     114.200000
# Western      136.666667
# Name: duration, dtype: float64

# %%
df3.groupby("genre").mean().plot(kind='bar')
# Out:
# <ipython-input-70-dbf4dd97afb8>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df3.groupby("genre").mean().plot(kind='bar')
# <Axes: xlabel='genre'>

# %%
df3.groupby("genre").agg(["max","min","sum","count","mean"]).head()   # agg takes aggregate functions, if attribute not mensioned, takes
                                                                      # all numeric attributes
# Out:
# <ipython-input-74-47766efe830e>:1: FutureWarning: ['title', 'content_rating', 'actors_list'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df3.groupby("genre").agg(["max","min","sum","count","mean"]).head()
#           star_rating                              duration                   \
#                   max  min     sum count      mean      max min    sum count
# genre
# Action            9.0  7.4  1072.3   136  7.884559      205  80  17202   136
# Adventure         8.9  7.4   595.0    75  7.933333      224  89  10113    75
# Animation         8.6  7.4   490.7    62  7.914516      134  75   5989    62
# Biography         8.9  7.4   605.4    77  7.862338      202  85  10152    77
# Comedy            8.6  7.4  1220.3   156  7.822436      187  68  16786   156
#
#
#                  mean
# genre
# Action     126.485294
# Adventure  134.840000
# Animation   96.596774
# ...

# %% [markdown]
# **15: Exploring pandas**

# %%
import pandas as pd

# %%
df3=pd.read_csv("/content/imdb_1000.csv")
df3.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df3.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
df3.genre.describe()
# Out:
# count       979
# unique       16
# top       Drama
# freq        278
# Name: genre, dtype: object

# %%
df3.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
df3.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
df3.genre.nunique()
# Out:
# 16

# %%
df3.genre.value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# **16: Handling missing values**

# %%
import pandas as pd

# %%
df16=pd.read_csv("/content/ufo.csv")
df16.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df16.isnull().head()
# Out:
#     City  Colors Reported  Shape Reported  State   Time
# 0  False             True           False  False  False
# 1  False             True           False  False  False
# 2  False             True           False  False  False
# 3  False             True           False  False  False
# 4  False             True           False  False  False

# %%
df16.notnull().head()
# Out:
#    City  Colors Reported  Shape Reported  State  Time
# 0  True            False            True   True  True
# 1  True            False            True   True  True
# 2  True            False            True   True  True
# 3  True            False            True   True  True
# 4  True            False            True   True  True

# %%
df16.isnull().sum()  # true converted to 1 and added; it tells number of missing values in each column
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
df16[df16.City.isnull()]  # filtering out those rows where city value is null
# Out:
#       City Colors Reported Shape Reported State              Time
# 21     NaN             NaN            NaN    LA    8/15/1943 0:00
# 22     NaN             NaN          LIGHT    LA    8/15/1943 0:00
# 204    NaN             NaN           DISK    CA   7/15/1952 12:30
# 241    NaN            BLUE           DISK    MT    7/4/1953 14:00
# 613    NaN             NaN           DISK    NV    7/1/1960 12:00
# 1877   NaN          YELLOW         CIRCLE    AZ    8/15/1969 1:00
# 2013   NaN             NaN            NaN    NH     8/1/1970 9:30
# 2546   NaN             NaN       FIREBALL    OH  10/25/1973 23:30
# 3123   NaN             RED       TRIANGLE    WV  11/25/1975 23:00
# 4736   NaN             NaN         SPHERE    CA   6/23/1982 23:00
# 5269   NaN             NaN            NaN    AZ   6/30/1985 21:30
# 6735   NaN             NaN      FORMATION    TX     4/1/1992 2:00
# 7208   NaN             NaN         CIRCLE    MI   10/4/1993 17:30
# ...

# %%
df16.shape
# Out:
# (18241, 5)

# %%
df16.dropna(how='any')
# Out:
#                City Colors Reported Shape Reported State              Time
# 12           Belton             RED         SPHERE    SC   6/30/1939 20:00
# 19       Bering Sea             RED          OTHER    AK   4/30/1943 23:00
# 36       Portsmouth             RED      FORMATION    VA    7/10/1945 1:30
# 44        Blairsden           GREEN         SPHERE    CA   6/30/1946 19:00
# 82         San Jose            BLUE        CHEVRON    CA   7/15/1947 21:00
# ...             ...             ...            ...   ...               ...
# 18213      Pasadena           GREEN       FIREBALL    CA  12/28/2000 19:10
# 18216  Garden Grove          ORANGE          LIGHT    CA  12/29/2000 16:10
# 18220   Shasta Lake            BLUE           DISK    CA  12/29/2000 20:30
# 18233     Anchorage             RED        VARIOUS    AK  12/31/2000 21:00
# 18239   Eagle River             RED          LIGHT    WI  12/31/2000 23:45
#
# [2486 rows x 5 columns]

# %%
df16.dropna(how='any').shape  # drop row if any of its attribute is NaN

# It is same as:
# df16.dropna(how='any', inplace=False).shape
# Out:
# (2486, 5)

# %%
df16.shape  # rows were temporarily droped as bydefault inplace=False
# Out:
# (18241, 5)

# %%
df16.dropna(how='all').shape # drop row if all of its attribute is NaN
# Out:
# (18241, 5)

# %%
df16.dropna(subset=["City","Colors Reported"], how='any').shape # drop row if all of its attribute is NaN
# Out:
# (2877, 5)

# %%
df16['Shape Reported'].value_counts(dropna=False)  # count of different values of this attribute
# Out:
# LIGHT        2803
# NaN          2644
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
df16["Shape Reported"].fillna(value="HEXAGON")
# Out:
# 0        TRIANGLE
# 1           OTHER
# 2            OVAL
# 3            DISK
# 4           LIGHT
#            ...
# 18236    TRIANGLE
# 18237        DISK
# 18238     HEXAGON
# 18239       LIGHT
# 18240        OVAL
# Name: Shape Reported, Length: 18241, dtype: object

# %%
df16['Shape Reported'].value_counts(dropna=False)
# Out:
# LIGHT        2803
# NaN          2644
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
df16["Shape Reported"].fillna(value="HEXAGON",inplace=True)

# %%
df16['Shape Reported'].value_counts(dropna=False)  # NaN values are filled with Hexagon
# Out:
# LIGHT        2803
# HEXAGON      2645
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# Name: Shape Reported, dtype: int64

# %%
# Q: fill missing values with the mean of an attribute

# %% [markdown]
# **17: Pandas indices**

# %%
df17=pd.read_csv("/content/ufo.csv")
df17.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df17.index
# Out:
# RangeIndex(start=0, stop=18241, step=1)

# %%
df17.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time'], dtype='object')

# %%
df17.shape
# Out:
# (18241, 5)

# %%
# identification using indices (filtering rows based on some attributes)

#df17[df17.City=="Ithaca"]

# OR
df17[df17['City']=="Ithaca"]   # Row index remains same
# Out:
#          City Colors Reported Shape Reported State              Time
# 0      Ithaca             NaN       TRIANGLE    NY    6/1/1930 22:00
# 4068   Ithaca             NaN          CIGAR    NY    6/1/1979 19:00
# 5631   Ithaca             NaN          OTHER    MI    6/1/1987 17:00
# 6961   Ithaca             NaN          OTHER    NY    1/10/1993 0:30
# 7573   Ithaca       RED GREEN          LIGHT    NY  10/15/1994 18:00
# 9088   Ithaca             NaN            NaN    NY   2/16/1996 21:45
# 16537  Ithaca             NaN          FLASH    MI    6/3/2000 22:35
# 17049  Ithaca             NaN       TEARDROP    NY   7/30/2000 20:20

# %%
# selection using index

df17.set_index("State",inplace=True)  # inplace means dataframe is updated
df17.head()                           # before this execution, set_index for City was done inplace, so it is not reflecting now in new df
# Out:
#                        City Colors Reported Shape Reported             Time
# State
# NY                   Ithaca             NaN       TRIANGLE   6/1/1930 22:00
# NJ              Willingboro             NaN          OTHER  6/30/1930 20:00
# CO                  Holyoke             NaN           OVAL  2/15/1931 14:00
# KS                  Abilene             NaN           DISK   6/1/1931 13:00
# NY     New York Worlds Fair             NaN          LIGHT  4/18/1933 19:00

# %%
df17.index
# Out:
# Index(['NY', 'NJ', 'CO', 'KS', 'NY', 'ND', 'CA', 'MI', 'AK', 'OR',
#        ...
#        'CA', 'WI', 'AK', 'CA', 'AZ', 'IL', 'IA', 'WI', 'WI', 'FL'],
#       dtype='object', name='State', length=18241)

# %%
df17.columns  # city and state are no longer columns
# Out:
# Index(['Colors Reported', 'Shape Reported', 'Time'], dtype='object')

# %%
df17.loc["NY","Shape Reported"]          # now we can select like this
# Out:
# State
# NY     TRIANGLE
# NY        LIGHT
# NY         DISK
# NY         DISK
# NY        CIGAR
#         ...
# NY     TRIANGLE
# NY        OTHER
# NY        LIGHT
# NY      VARIOUS
# NY    FORMATION
# Name: Shape Reported, Length: 914, dtype: object

# %%
df17.reset_index(inplace=True)
df17.head()
# Out:
#   State                  City Colors Reported Shape Reported             Time
# 0    NY                Ithaca             NaN       TRIANGLE   6/1/1930 22:00
# 1    NJ           Willingboro             NaN          OTHER  6/30/1930 20:00
# 2    CO               Holyoke             NaN           OVAL  2/15/1931 14:00
# 3    KS               Abilene             NaN           DISK   6/1/1931 13:00
# 4    NY  New York Worlds Fair             NaN          LIGHT  4/18/1933 19:00

# %%
# indices can be used to study the resulting dataframes such as describe()

a=df17.describe()
a
# Out:
#         State     City Colors Reported Shape Reported              Time
# count   18241    18216            2882          15597             18241
# unique     52     6476              27             27             16145
# top        CA  Seattle             RED          LIGHT  11/16/1999 19:00
# freq     2529      187             780           2803                27

# %%
a.loc['top','City']  # values can be accessed using indices from the resulting dataset
# Out:
# 'Seattle'

# %% [markdown]
# **18: Indices**

# %%
# Similar to dataframe, dataseries too has index

df17=pd.read_csv("/content/ufo.csv")
df17.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df17.set_index("State",inplace=True)
df17.head()
# Out:
#                        City Colors Reported Shape Reported             Time
# State
# NY                   Ithaca             NaN       TRIANGLE   6/1/1930 22:00
# NJ              Willingboro             NaN          OTHER  6/30/1930 20:00
# CO                  Holyoke             NaN           OVAL  2/15/1931 14:00
# KS                  Abilene             NaN           DISK   6/1/1931 13:00
# NY     New York Worlds Fair             NaN          LIGHT  4/18/1933 19:00

# %%
df17['City'].head()
# Out:
# State
# NY                  Ithaca
# NJ             Willingboro
# CO                 Holyoke
# KS                 Abilene
# NY    New York Worlds Fair
# Name: City, dtype: object

# %%
df17.City.value_counts()
# Out:
# Seattle                       187
# New York City                 161
# Phoenix                       137
# Houston                       108
# Las Vegas                     105
#                              ...
# Neb.-Mo. Line                   1
# Carlsberg                       1
# Yukon                           1
# Dolly Sods Wilderness Area      1
# Ybor                            1
# Name: City, Length: 6476, dtype: int64

# %%
df17.City.value_counts().index
# Out:
# Index(['Seattle', 'New York City', 'Phoenix', 'Houston', 'Las Vegas',
#        'Portland', 'San Diego', 'Los Angeles', 'Chicago', 'Austin',
#        ...
#        'Walker Valle', 'Azucena', 'Sutcliff', 'Buchanan', 'Splendora',
#        'Neb.-Mo. Line', 'Carlsberg', 'Yukon', 'Dolly Sods Wilderness Area',
#        'Ybor'],
#       dtype='object', length=6476)

# %%
df17.City.value_counts().values
# Out:
# array([187, 161, 137, ...,   1,   1,   1])

# %% [markdown]
# **19: loc, iloc, ix: Selecting multiple rows and columns from a pandas DataFrame**

# %%
import pandas as pd
df17=pd.read_csv("/content/ufo.csv")
df17.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df17.loc[0,:] # row 0, all columns
# Out:
# City                       Ithaca
# Colors Reported               NaN
# Shape Reported           TRIANGLE
# State                          NY
# Time               6/1/1930 22:00
# Name: 0, dtype: object

# %%
df17.loc[0] # same as above, if , is missing takes all columns
# Out:
# City                       Ithaca
# Colors Reported               NaN
# Shape Reported           TRIANGLE
# State                          NY
# Time               6/1/1930 22:00
# Name: 0, dtype: object

# %%
df17.loc[[0,1,2,3],:] # row 0,1,2,3; all columns: loc is inclusive on both sides
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3      Abilene             NaN           DISK    KS   6/1/1931 13:00

# %%
df17.loc[0:2]  # syntax is row,col but if , not there it assumes all cols
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
df17.loc[0:2,:]  # previous is equal to this; inclusive on both sides
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
df17.loc[:,"City"] # all rows and city attribute
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
#                  ...
# 18236              Grant Park
# 18237             Spirit Lake
# 18238             Eagle River
# 18239             Eagle River
# 18240                    Ybor
# Name: City, Length: 18241, dtype: object

# %%
df17.loc[:,["City","State"]]  # all rows and multiple cols
# Out:
#                        City State
# 0                    Ithaca    NY
# 1               Willingboro    NJ
# 2                   Holyoke    CO
# 3                   Abilene    KS
# 4      New York Worlds Fair    NY
# ...                     ...   ...
# 18236            Grant Park    IL
# 18237           Spirit Lake    IA
# 18238           Eagle River    WI
# 18239           Eagle River    WI
# 18240                  Ybor    FL
#
# [18241 rows x 2 columns]

# %%
df17.loc[:,"City":"State"]  # all rows and from city to state
# Out:
#                        City Colors Reported Shape Reported State
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
# [18241 rows x 4 columns]

# %%
df17.iloc[:,0:3]  # inclusive of first and exclusive of second range
# Out:
#                        City Colors Reported Shape Reported
# 0                    Ithaca             NaN       TRIANGLE
# 1               Willingboro             NaN          OTHER
# 2                   Holyoke             NaN           OVAL
# 3                   Abilene             NaN           DISK
# 4      New York Worlds Fair             NaN          LIGHT
# ...                     ...             ...            ...
# 18236            Grant Park             NaN       TRIANGLE
# 18237           Spirit Lake             NaN           DISK
# 18238           Eagle River             NaN            NaN
# 18239           Eagle River             RED          LIGHT
# 18240                  Ybor             NaN           OVAL
#
# [18241 rows x 3 columns]

# %%
df17.loc[1:4,"City":"State"]
# Out:
#                    City Colors Reported Shape Reported State
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY

# %%
# instead of providing indices, we can provide conditions to loc

df17.loc[df17.City=="Holyoke",:]
# Out:
#           City Colors Reported Shape Reported State              Time
# 2      Holyoke             NaN           OVAL    CO   2/15/1931 14:00
# 771    Holyoke             NaN           DISK    MA   1/20/1963 22:00
# 3221   Holyoke             NaN           DISK    MA    6/5/1976 23:00
# 7982   Holyoke             NaN          LIGHT    MA    4/1/1995 18:00
# 18211  Holyoke             NaN        DIAMOND    MA  12/28/2000 18:00

# %%
#df17.loc[df17.City=="Holyoke","State"]

# Or

df17.loc[df17.City=="Holyoke"].State       # both these are equivalent but still above one is prefrred in some conditions
# Out:
# 2        CO
# 771      MA
# 3221     MA
# 7982     MA
# 18211    MA
# Name: State, dtype: object

# %%
# iloc: integer position

df17.iloc[:,0:4].head()  # includes first and excludes second
# Out:
#                    City Colors Reported Shape Reported State
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY

# %%
df17.iloc[:,[0,1,2]].head()
# Out:
#                    City Colors Reported Shape Reported
# 0                Ithaca             NaN       TRIANGLE
# 1           Willingboro             NaN          OTHER
# 2               Holyoke             NaN           OVAL
# 3               Abilene             NaN           DISK
# 4  New York Worlds Fair             NaN          LIGHT

# %%
# ix: allows to mix integer and labels

# dont use it

# %% [markdown]
# **20: When to use the "inplace" parameter in pandas?**

# %%
# methods have inplace=False by defualt (drop(),dropna(),rename(),sort_values(),set_index())
# we can use inplace=True or an assignment statement

# %% [markdown]
# **21: Making pandas DataFrame smaller and faster**

# %%
import pandas as pd
df=pd.read_csv("/content/imdb_1000.csv")
df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   star_rating     979 non-null    float64
#  1   title           979 non-null    object
#  2   content_rating  976 non-null    object
#  3   genre           979 non-null    object
#  4   duration        979 non-null    int64
#  5   actors_list     979 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 309.5 KB

# %%
df.memory_usage()
# Out:
# Index              128
# star_rating       7832
# title             7832
# content_rating    7832
# genre             7832
# duration          7832
# actors_list       7832
# dtype: int64

# %%
# calculate the memory usage for each Series (in bytes)
df.memory_usage(deep=True)
# Out:
# Index                128
# star_rating         7832
# title              70959
# content_rating     58730
# genre              61963
# duration            7832
# actors_list       109533
# dtype: int64

# %%
# use the 'category' data type (new in pandas 0.15) to store the 'gemre' strings as integers
df['genre'] = df.genre.astype('category')
df.dtypes
# Out:
# star_rating        float64
# title               object
# content_rating      object
# genre             category
# duration             int64
# actors_list         object
# dtype: object

# %%
# 'genre' Series appears to be unchanged
df.genre.head()
# Out:
# 0     Crime
# 1     Crime
# 2     Crime
# 3    Action
# 4     Crime
# Name: genre, dtype: category
# Categories (16, object): ['Action', 'Adventure', 'Animation', 'Biography', ..., 'Mystery', 'Sci-Fi',
#                           'Thriller', 'Western']

# %%
# strings are now encoded
df.genre.cat.codes.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    0
# 4    5
# dtype: int8

# %%
# memory usage has been drastically reduced
df.memory_usage(deep=True)
# Out:
# Index                128
# star_rating         7832
# title              70959
# content_rating     58730
# genre               2559
# duration            7832
# actors_list       109533
# dtype: int64

# %%
# repeat this process for the 'title' Series
df['title'] = df.title.astype('category')
df.memory_usage(deep=True)
# Out:
# Index                128
# star_rating         7832
# title             105692
# content_rating     58730
# genre               2559
# duration            7832
# actors_list       109533
# dtype: int64

# %%
df.shape
# Out:
# (979, 6)

# %%
df.title.nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0                             The Shawshank Redemption
# 1                                        The Godfather
# 2                               The Godfather: Part II
# 3                                      The Dark Knight
# 4                                         Pulp Fiction
#                             ...
# 974                                            Tootsie
# 975                        Back to the Future Part III
# 976    Master and Commander: The Far Side of the World
# 977                                        Poltergeist
# 978                                        Wall Street
# Name: title, Length: 979, dtype: category
# Categories (975, object): ['(500) Days of Summer', '12 Angry Men', '12 Years a Slave', '127 Hours', ...,
#                            'Zodiac', 'Zombieland', 'Zulu', '[Rec]']>

# %%
df.genre.nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0          Crime
# 1          Crime
# 2          Crime
# 3         Action
# 4          Crime
#          ...
# 974       Comedy
# 975    Adventure
# 976       Action
# 977       Horror
# 978        Crime
# Name: genre, Length: 979, dtype: category
# Categories (16, object): ['Action', 'Adventure', 'Animation', 'Biography', ..., 'Mystery', 'Sci-Fi',
#                           'Thriller', 'Western']>

# %%
# create a small DataFrame from a dictionary
df = pd.DataFrame({'ID':[100, 101, 102, 103], 'quality':['good', 'very good', 'good', 'excellent']})
df
# Out:
#     ID    quality
# 0  100       good
# 1  101  very good
# 2  102       good
# 3  103  excellent

# %%
# sort the DataFrame by the 'quality' Series (alphabetical order)
df.sort_values('quality')
# Out:
#     ID    quality
# 3  103  excellent
# 0  100       good
# 2  102       good
# 1  101  very good

# %%
# Create a dataframe
import pandas as pd
df = pd.DataFrame({'ID':[100, 101, 102, 103], 'quality':['good', 'very good', 'good', 'excellent']})
df
# Out:
#     ID    quality
# 0  100       good
# 1  101  very good
# 2  102       good
# 3  103  excellent

# %%
# logical sorting by converting into categories
df["quality"]=df["quality"].replace({"good":0,"very good":1,"excellent":2})
df
# Out:
#     ID  quality
# 0  100        0
# 1  101        1
# 2  102        0
# 3  103        2

# %%
df.sort_values("quality")
# Out:
#     ID  quality
# 0  100        0
# 2  102        0
# 1  101        1
# 3  103        2

# %%
# comparison operators work with ordered categories
df.loc[df.quality > 1, :]
# Out:
#     ID  quality
# 3  103        2

# %%
# Another way to convert into category
# Create a dataframe
import pandas as pd
df = pd.DataFrame({'ID':[100, 101, 102, 103], 'quality':['good', 'very good', 'good', 'excellent']})
df
# Out:
#     ID    quality
# 0  100       good
# 1  101  very good
# 2  102       good
# 3  103  excellent

# %%
df.sort_values("quality")
# Out:
#     ID    quality
# 3  103  excellent
# 0  100       good
# 2  102       good
# 1  101  very good

# %%
df["new"] = pd.Categorical(df.quality, categories=["excellent", "very good", "good"],ordered=True)

# %%
# now logical sorting is done
df.sort_values("new",ascending=True)
# Out:
#     ID    quality        new
# 3  103  excellent  excellent
# 1  101  very good  very good
# 0  100       good       good
# 2  102       good       good

# %%
# Above two methods to convert an attribute to category are not working well. This is the modified version that performs correct logical sorting

import pandas as pd

# Create a DataFrame
data = {'fruits': ['Apple', 'Banana', 'Orange', 'Banana', 'Apple', 'Orange']}
df = pd.DataFrame(data)

# Convert the 'fruits' column to a categorical variable
df['fruits'] = pd.Categorical(df['fruits'], categories=['Orange', 'Apple', 'Banana'], ordered=True)

# Perform logical sorting based on the categorical variable
df = df.sort_values('fruits')

# Display the sorted DataFrame
df[df.fruits>"Apple"]
# Out:
#    fruits
# 1  Banana
# 3  Banana

# %% [markdown]
# **22: kaggle and sklearn**

# %% [markdown]
# **23: Q&A**

# %%
# What is the difference between ufo.isnull() and pd.isnull(ufo)?

# %%
import pandas as pd
df=pd.read_csv("/content/ufo.csv")
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
pd.isnull(df).head()
# Out:
#     City  Colors Reported  Shape Reported  State   Time
# 0  False             True           False  False  False
# 1  False             True           False  False  False
# 2  False             True           False  False  False
# 3  False             True           False  False  False
# 4  False             True           False  False  False

# %%
df.isnull().head()  # both are same
# Out:
#     City  Colors Reported  Shape Reported  State   Time
# 0  False             True           False  False  False
# 1  False             True           False  False  False
# 2  False             True           False  False  False
# 3  False             True           False  False  False
# 4  False             True           False  False  False

# %%
# random sampling
df.sample(n=4)  # random 4 rows
# Out:
#            City Colors Reported Shape Reported State              Time
# 16112   Everett             NaN          LIGHT    WA   3/18/2000 20:20
# 8890   Simsbury             NaN            NaN    CT  11/17/1995 17:18
# 2321    Fortuna             NaN         SPHERE    CA   10/5/1972 21:45
# 3145     Millis             NaN            NaN    MA    1/20/1976 2:00

# %%
df.sample(n=4,random_state=300)  # same results everytime
# Out:
#           City Colors Reported Shape Reported State             Time
# 1692      Zell             NaN           DISK    SD  7/20/1968 15:00
# 6552  Marshall             NaN           DISK    MI  5/31/1991 13:00
# 6673  Westwood             NaN          LIGHT    CA  9/23/1991 19:30
# 6805  Gastonia             NaN         SPHERE    NC  6/15/1992 22:00

# %%
df.sample(frac=0.10,random_state=300)  # gets 10% of the rows
# Out:
#                   City Colors Reported Shape Reported State             Time
# 1692              Zell             NaN           DISK    SD  7/20/1968 15:00
# 6552          Marshall             NaN           DISK    MI  5/31/1991 13:00
# 6673          Westwood             NaN          LIGHT    CA  9/23/1991 19:30
# 6805          Gastonia             NaN         SPHERE    NC  6/15/1992 22:00
# 2622          Ore City             NaN         CIRCLE    TX   6/1/1974 10:00
# ...                ...             ...            ...   ...              ...
# 4301       Victorville             NaN          LIGHT    CA   6/1/1980 11:00
# 15007      Baton Rouge             NaN       TRIANGLE    LA  11/2/1999 19:15
# 502        Cheektowaga             NaN       TEARDROP    NY   7/10/1958 9:00
# 1577   Franconia Notch             NaN         CIRCLE    NH   5/1/1968 14:00
# 8192        Kingsville             NaN          OTHER    OH   6/1/1995 22:00
#
# [1824 rows x 5 columns]

# %%
#Q: Train test split
train=df.sample(frac=0.75)
test=df.loc[~df.index.isin(train.index),:]

# %%
train.head()
# Out:
#                  City    Colors Reported Shape Reported State             Time
# 4626      Andrews AFB                NaN         CIRCLE    MD  9/20/1981 18:00
# 12864      Chatsworth              GREEN          LIGHT    CA   1/7/1999 18:20
# 8544   Salt Lake City                NaN            NaN    UT  8/18/1995 15:00
# 4921          Swayzee  YELLOW GREEN BLUE            NaN    IN    7/1/1983 1:30
# 6984             Mesa                NaN          OTHER    AZ   3/1/1993 12:00

# %%
test.head()
# Out:
#            City Colors Reported Shape Reported State             Time
# 5   Valley City             NaN           DISK    ND  9/15/1934 15:30
# 7          Alma             NaN           DISK    MI   7/15/1936 0:00
# 10      Fontana             NaN          LIGHT    CA  8/15/1937 21:00
# 11     Waterloo             NaN       FIREBALL    AL   6/1/1939 20:00
# 13       Keokuk             NaN           OVAL    IA    7/7/1939 2:00

# %% [markdown]
# **24: Creating dummy variables**

# %%
# read the training dataset from Kaggle's Titanic competition
df1= pd.read_csv('http://bit.ly/kaggletrain')
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df1.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
# use 'get_dummies' with a feature that has 3 possible values
df2=pd.get_dummies(df1.Embarked, prefix='Embarked')
df2.head()
# Out:
#    Embarked_C  Embarked_Q  Embarked_S
# 0           0           0           1
# 1           1           0           0
# 2           0           0           1
# 3           0           0           1
# 4           0           0           1

# %%
# drop the first dummy variable ('C'))
df2=df2.drop("Embarked_C", axis=1)
df2.head()
# Out:
#    Embarked_Q  Embarked_S
# 0           0           1
# 1           0           0
# 2           0           1
# 3           0           1
# 4           0           1

# %%
# save the DataFrame of dummy variables and concatenate them to the original DataFrame
df3 = pd.concat([df1, df2], axis=1)
df3.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Embarked_Q  Embarked_S
# 0      0         A/5 21171   7.2500   NaN        S           0           1
# 1      0          PC 17599  71.2833   C85        C           0           0
# 2      0  STON/O2. 3101282   7.9250   NaN        S           0           1
# ...

# %%
# upto now we passed series to dataframe, how to pass data frame?
# reset the DataFrame
df4= pd.read_csv('http://bit.ly/kaggletrain')
df4.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# pass the DataFrame to 'get_dummies' and specify which columns to dummy (it drops the original columns)
pd.get_dummies(df4, columns=['Sex', 'Embarked']).head()  # all done at once; original columns dropped and new once created
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin  Sex_female  Sex_male  Embarked_C  \
# 0         A/5 21171   7.2500   NaN           0         1           0
# 1          PC 17599  71.2833   C85           1         0           1
# 2  STON/O2. 3101282   7.9250   NaN           1         0           0
# ...

# %%
# we can drop manually or
# use the 'drop_first' parameter (new in pandas 0.18) to drop the first dummy variable for each feature
pd.get_dummies(df4, columns=['Sex', 'Embarked'], drop_first=True).head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0      1      0
# 2                             Heikkinen, Miss. Laina  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0      1      0
# 4                           Allen, Mr. William Henry  35.0      0      0
#
#              Ticket     Fare Cabin  Sex_male  Embarked_Q  Embarked_S
# 0         A/5 21171   7.2500   NaN         1           0           1
# 1          PC 17599  71.2833   C85         0           0           0
# 2  STON/O2. 3101282   7.9250   NaN         0           0           1
# ...

# %% [markdown]
# **25: Date and time**

# %%
import pandas as pd
df=pd.read_csv("/content/ufo.csv")
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
# 'Time' is currently stored as a string
df.dtypes
# Out:
# City               object
# Colors Reported    object
# Shape Reported     object
# State              object
# Time               object
# dtype: object

# %%
# hour could be accessed using string slicing
df.Time.str.slice(-5, -3)
# Out:
# 0        22
# 1        20
# 2        14
# 3        13
# 4        19
#          ..
# 18236    23
# 18237    23
# 18238    23
# 18239    23
# 18240    23
# Name: Time, Length: 18241, dtype: object

# %%
# it is still string, converting into int
df.Time.str.slice(-5, -3).astype(int).head()
# Out:
# 0    22
# 1    20
# 2    14
# 3    13
# 4    19
# Name: Time, dtype: int64

# %%
# convert 'Time' to datetime format
df['Time'] = pd.to_datetime(df.Time)
df.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time
# 0 1930-06-01 22:00:00
# 1 1930-06-30 20:00:00
# 2 1931-02-15 14:00:00
# 3 1931-06-01 13:00:00
# 4 1933-04-18 19:00:00

# %%
df.dtypes
# Out:
# City                       object
# Colors Reported            object
# Shape Reported             object
# State                      object
# Time               datetime64[ns]
# dtype: object

# %%
# convenient Series attributes are now available
df.Time.dt.hour.head()
# Out:
# 0    22
# 1    20
# 2    14
# 3    13
# 4    19
# Name: Time, dtype: int64

# %%
# ufo.Time.dt.weekday_name.head() ##################

# %%
df.Time.dt.dayofyear.head()
# Out:
# 0    152
# 1    181
# 2     46
# 3    152
# 4    108
# Name: Time, dtype: int64

# %%
# convert a single string to datetime format (outputs a timestamp object)
ts = pd.to_datetime('1/1/1999')
ts
# Out:
# Timestamp('1999-01-01 00:00:00')

# %%
# compare a datetime Series with a timestamp
df.loc[df.Time >= ts, :].head()
# Out:
#                     City Colors Reported Shape Reported State  \
# 12832          Loma Rica             NaN          LIGHT    CA
# 12833            Bauxite             NaN            NaN    AR
# 12834           Florence             NaN       CYLINDER    SC
# 12835       Lake Henshaw             NaN          CIGAR    CA
# 12836  Wilmington Island             NaN          LIGHT    GA
#
#                      Time
# 12832 1999-01-01 02:30:00
# 12833 1999-01-01 03:00:00
# 12834 1999-01-01 14:00:00
# 12835 1999-01-01 15:00:00
# 12836 1999-01-01 17:15:00

# %%
df.Time.max() # latest timestamp in dataset
# Out:
# Timestamp('2000-12-31 23:59:00')

# %%
# perform mathematical operations with timestamps (outputs a timedelta object)
df.Time.max() - df.Time.min()
# Out:
# Timedelta('25781 days 01:59:00')

# %%
# timedelta objects also have attributes you can access
(df.Time.max() - df.Time.min()).days
# Out:
# 25781

# %%
# allow plots to appear in the notebook
# %matplotlib inline

# %%
# count the number of UFO reports per year
df['Year'] = df.Time.dt.year
df.Year.value_counts().sort_index().head()
# Out:
# 1930    2
# 1931    2
# 1933    1
# 1934    1
# 1935    1
# Name: Year, dtype: int64

# %%
# plot the number of UFO reports per year (line plot is the default)
df.Year.value_counts().sort_index().plot()
# Out:
# <Axes: >

# %% [markdown]
# **26: Finding and removing Duplicate rows**

# %%
import pandas as pd
heading=["c1","c2","c3","c4","c5"]
df=pd.read_csv("/content/u.user", sep="|",header=None,names=heading)
df.head()
# Out:
#    c1  c2 c3          c4     c5
# 0   1  24  M  technician  85711
# 1   2  53  F       other  94043
# 2   3  23  M      writer  32067
# 3   4  24  M  technician  43537
# 4   5  33  F       other  15213

# %%
df.shape
# Out:
# (943, 5)

# %%
# detect duplicate zip codes: True if an item is identical to a previous item
df.c5.duplicated().tail()
# Out:
# 938    False
# 939     True
# 940    False
# 941    False
# 942    False
# Name: c5, dtype: bool

# %%
# count the duplicate items (True becomes 1, False becomes 0)
df.c5.duplicated().sum()
# Out:
# 148

# %%
# detect duplicate DataFrame rows: True if an entire row is identical to a previous row
df.duplicated().tail()
# Out:
# 938    False
# 939    False
# 940    False
# 941    False
# 942    False
# dtype: bool

# %%
# count the duplicate rows
df.duplicated().sum()
# Out:
# 0

# %%
'''
Logic for duplicated:

keep='first' (default): Mark duplicates as True except for the first occurrence.
keep='last': Mark duplicates as True except for the last occurrence.
keep=False: Mark all duplicates as True.

'''

# %%
# examine the duplicate rows (ignoring the first occurrence)
df.loc[df.duplicated(keep='first'), :]
# Out:
# Empty DataFrame
# Columns: [c1, c2, c3, c4, c5]
# Index: []

# %%
# examine the duplicate rows (ignoring the last occurrence)
df.loc[df.duplicated(keep='last'), :]
# Out:
# Empty DataFrame
# Columns: [c1, c2, c3, c4, c5]
# Index: []

# %%
# examine the duplicate rows (including all duplicates)
df.loc[df.duplicated(keep=False), :]

# %%
# drop the duplicate rows (inplace=False by default)
df.drop_duplicates(keep='first').shape

# %%
df.drop_duplicates(keep='last').shape

# %%
df.drop_duplicates(keep=False).shape

# %%
# only consider a subset of columns when identifying duplicates
df.duplicated(subset=['c2', 'c4']).sum()
# Out:
# 514

# %%
df.drop_duplicates(subset=['c2','c4']).shape
# Out:
# (429, 5)

# %% [markdown]
# **28: How to change display options**

# %%
import pandas as pd
df=pd.read_csv("/content/imdb_1000.csv")
df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df.shape
# Out:
# (979, 6)

# %%
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
# check the current setting for the 'max_rows' option
pd.get_option('display.max_rows')
# Out:
# 60

# %%
# overwrite the current setting so that all rows will be displayed
pd.set_option('display.max_rows', None)  # instead of None write the no. of rows to be printed
# printing df now, None will print all the rows

# %%
# reset the 'max_rows' option to its default
pd.reset_option('display.max_rows')

# %%
# the 'max_columns' option is similar to 'max_rows'
pd.get_option('display.max_columns')  # default value is 20; similarly we can change to the number we want
# Out:
# 20

# %%
# read the training dataset from Kaggle's Titanic competition into a DataFrame
train = pd.read_csv('http://bit.ly/kaggletrain')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# an ellipsis is displayed in the 'Name' cell of row 1 because of the 'max_colwidth' option
pd.get_option('display.max_colwidth')
# Out:
# 50

# %%
# overwrite the current setting so that more characters will be displayed
pd.set_option('display.max_colwidth', 1000)  # it will show text upto 1000 length
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
# overwrite the 'precision' setting to display 2 digits after the decimal point of 'Fare'
pd.set_option('display.precision', 2)
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket   Fare Cabin Embarked
# 0      0         A/5 21171   7.25   NaN        S
# 1      0          PC 17599  71.28   C85        C
# 2      0  STON/O2. 3101282   7.92   NaN        S
# 3      0            113803  53.10  C123        S
# 4      0            373450   8.05   NaN        S

# %%
# add two meaningless columns to the drinks DataFrame
train['x'] = train.Fare * 1000
train['y'] = train.PassengerId * 1000
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket   Fare Cabin Embarked        x     y
# 0      0         A/5 21171   7.25   NaN        S   7250.0  1000
# 1      0          PC 17599  71.28   C85        C  71283.3  2000
# 2      0  STON/O2. 3101282   7.92   NaN        S   7925.0  3000
# ...

# %%
# use a Python format string to specify a comma as the thousands separator
pd.set_option('display.float_format', '{:,}'.format)  # it only affects floating point formats, there is no method for integers
train.head()

# %%
# 'y' was affected (but not 'x') because the 'float_format' option only affects floats (not ints)
train.dtypes

# %%
# view the option descriptions (including the default and current values)
pd.describe_option()

# %%
# search for specific options by name
pd.describe_option('rows')

# %%
# reset all of the options to their default values
pd.reset_option('all')

# %% [markdown]
# **29: How do I create a pandas DataFrame from another object?**:

# %%
import pandas as pd

# %%
# create a DataFrame from a dictionary (keys become column names, values become data)
pd.DataFrame({'id':[100, 101, 102], 'color':['red', 'blue', 'red'],'index':[1,2,3]})
# Out:
#     id color  index
# 0  100   red      1
# 1  101  blue      2
# 2  102   red      3

# %%
# optionally specify the order of columns and define the index
df = pd.DataFrame({'id':[100, 101, 102], 'color':['red', 'blue', 'red']}, columns=['color', 'id'], index=['a', 'b', 'c'])
df
# Out:
#   color   id
# a   red  100
# b  blue  101
# c   red  102

# %%
# create a DataFrame from a list of lists (each inner list becomes a row)
pd.DataFrame([[100, 'red'], [101, 'blue'], [102, 'red']], columns=['color', 'id'],index=[1,2,3])
# Out:
#    color    id
# 1    100   red
# 2    101  blue
# 3    102   red

# %% [markdown]
# **30: How do I apply a function to a pandas Series or DataFrame?**

# %%
# apply method applies a function to each value of the series
import pandas as pd
df=pd.read_csv("/content/imdb_1000.csv")
df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
# calculate the length of each string in the 'Name' Series
df['Name_length'] = df.title.apply(len)
df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                                 actors_list  Name_length
# 0        [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']           24
# 1           [u'Marlon Brando', u'Al Pacino', u'James Caan']           13
# 2       [u'Al Pacino', u'Robert De Niro', u'Robert Duvall']           22
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron Eckhart']           15
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L. Jackson']           12

# %%
def fxn(val):
  if val=="Crime":
    df["new"]=df["star_rating"]*2

# %%
df.genre.apply(fxn)
# Out:
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 974    None
# 975    None
# 976    None
# 977    None
# 978    None
# Name: genre, Length: 979, dtype: object

# %%
df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list   new
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...  18.6
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']  18.4
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...  18.2
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...  18.0
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....  17.8

# %% [markdown]
# **31: MultiIndex**

# %%
import pandas as pd
df=pd.read_csv("/content/stocks.csv")
df
# Out:
#          Date   Close    Volume Symbol
# 0  2016-10-03   31.50  14070500   CSCO
# 1  2016-10-03  112.52  21701800   AAPL
# 2  2016-10-03   57.42  19189500   MSFT
# 3  2016-10-04  113.00  29736800   AAPL
# 4  2016-10-04   57.24  20085900   MSFT
# 5  2016-10-04   31.35  18460400   CSCO
# 6  2016-10-05   57.64  16726400   MSFT
# 7  2016-10-05   31.59  11808600   CSCO
# 8  2016-10-05  113.05  21453100   AAPL

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
df.groupby('Symbol').mean()
# Out:
# <ipython-input-2-a15e42560add>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Symbol').mean()
#              Close        Volume
# Symbol
# AAPL    112.856667  2.429723e+07
# CSCO     31.480000  1.477983e+07
# MSFT     57.433333  1.866727e+07

# %%
df.groupby('Symbol').Close.mean()
# Out:
# Symbol
# AAPL    112.856667
# CSCO     31.480000
# MSFT     57.433333
# Name: Close, dtype: float64

# %%
ser = df.groupby(['Symbol', 'Date']).Close.mean()
ser
# Out:
# Symbol  Date
# AAPL    2016-10-03    112.52
#         2016-10-04    113.00
#         2016-10-05    113.05
# CSCO    2016-10-03     31.50
#         2016-10-04     31.35
#         2016-10-05     31.59
# MSFT    2016-10-03     57.42
#         2016-10-04     57.24
#         2016-10-05     57.64
# Name: Close, dtype: float64

# %%
ser.index
# Out:
# MultiIndex([('AAPL', '2016-10-03'),
#             ('AAPL', '2016-10-04'),
#             ('AAPL', '2016-10-05'),
#             ('CSCO', '2016-10-03'),
#             ('CSCO', '2016-10-04'),
#             ('CSCO', '2016-10-05'),
#             ('MSFT', '2016-10-03'),
#             ('MSFT', '2016-10-04'),
#             ('MSFT', '2016-10-05')],
#            names=['Symbol', 'Date'])

# %%
# multi index adds another dimension to the data
# series with 2 index is a dataframe
ser.unstack()
# Out:
# Date    2016-10-03  2016-10-04  2016-10-05
# Symbol
# AAPL        112.52      113.00      113.05
# CSCO         31.50       31.35       31.59
# MSFT         57.42       57.24       57.64

# %%
ser
# Out:
# Symbol  Date
# AAPL    2016-10-03    112.52
#         2016-10-04    113.00
#         2016-10-05    113.05
# CSCO    2016-10-03     31.50
#         2016-10-04     31.35
#         2016-10-05     31.59
# MSFT    2016-10-03     57.42
#         2016-10-04     57.24
#         2016-10-05     57.64
# Name: Close, dtype: float64

# %%
# Selection using multiindex
ser.loc['AAPL']
# Out:
# Date
# 2016-10-03    112.52
# 2016-10-04    113.00
# 2016-10-05    113.05
# Name: Close, dtype: float64

# %%
ser.loc['AAPL', '2016-10-03']
# Out:
# 112.52

# %%
ser.loc[:, '2016-10-03']
# Out:
# Symbol
# AAPL    112.52
# CSCO     31.50
# MSFT     57.42
# Name: Close, dtype: float64

# %%
# dataframe with multiindex

df.set_index(['Symbol', 'Date'], inplace=True)
df
# Out:
#                     Close    Volume
# Symbol Date
# CSCO   2016-10-03   31.50  14070500
# AAPL   2016-10-03  112.52  21701800
# MSFT   2016-10-03   57.42  19189500
# AAPL   2016-10-04  113.00  29736800
# MSFT   2016-10-04   57.24  20085900
# CSCO   2016-10-04   31.35  18460400
# MSFT   2016-10-05   57.64  16726400
# CSCO   2016-10-05   31.59  11808600
# AAPL   2016-10-05  113.05  21453100

# %%
df.index
# Out:
# MultiIndex([('CSCO', '2016-10-03'),
#             ('AAPL', '2016-10-03'),
#             ('MSFT', '2016-10-03'),
#             ('AAPL', '2016-10-04'),
#             ('MSFT', '2016-10-04'),
#             ('CSCO', '2016-10-04'),
#             ('MSFT', '2016-10-05'),
#             ('CSCO', '2016-10-05'),
#             ('AAPL', '2016-10-05')],
#            names=['Symbol', 'Date'])

# %%
df.sort_index(inplace=True)
df  # sort by first outer index and then inner index
# Out:
#                     Close    Volume
# Symbol Date
# AAPL   2016-10-03  112.52  21701800
#        2016-10-04  113.00  29736800
#        2016-10-05  113.05  21453100
# CSCO   2016-10-03   31.50  14070500
#        2016-10-04   31.35  18460400
#        2016-10-05   31.59  11808600
# MSFT   2016-10-03   57.42  19189500
#        2016-10-04   57.24  20085900
#        2016-10-05   57.64  16726400

# %%
# selection of dataframe from multiindex
df.loc['AAPL']
# Out:
#              Close    Volume
# Date
# 2016-10-03  112.52  21701800
# 2016-10-04  113.00  29736800
# 2016-10-05  113.05  21453100

# %%
df.loc[('AAPL', '2016-10-03'), :]
# Out:
# Close          112.52
# Volume    21701800.00
# Name: (AAPL, 2016-10-03), dtype: float64

# %%
df.loc[('AAPL', '2016-10-03'), 'Close']
# Out:
# 112.52

# %%
df.loc[['AAPL', 'MSFT'], :]
# Out:
#                     Close    Volume
# Symbol Date
# AAPL   2016-10-03  112.52  21701800
#        2016-10-04  113.00  29736800
#        2016-10-05  113.05  21453100
# MSFT   2016-10-03   57.42  19189500
#        2016-10-04   57.24  20085900
#        2016-10-05   57.64  16726400

# %%
df.loc[(['AAPL', 'MSFT'], '2016-10-03'), :]
# Out:
#                     Close    Volume
# Symbol Date
# AAPL   2016-10-03  112.52  21701800
# MSFT   2016-10-03   57.42  19189500

# %%
df.loc[(['AAPL', 'MSFT'], '2016-10-03'), 'Close']
# Out:
# Symbol  Date
# AAPL    2016-10-03    112.52
# MSFT    2016-10-03     57.42
# Name: Close, dtype: float64

# %%
df.loc[('AAPL', ['2016-10-03', '2016-10-04']), 'Close']
# Out:
# Symbol  Date
# AAPL    2016-10-03    112.52
#         2016-10-04    113.00
# Name: Close, dtype: float64

# %%
df.loc[(slice(None), ['2016-10-03', '2016-10-04']), :]
# Out:
#                     Close    Volume
# Symbol Date
# AAPL   2016-10-03  112.52  21701800
#        2016-10-04  113.00  29736800
# CSCO   2016-10-03   31.50  14070500
#        2016-10-04   31.35  18460400
# MSFT   2016-10-03   57.42  19189500
#        2016-10-04   57.24  20085900

# %%
# Merging dataframes with multi indexes:

close = pd.read_csv('/content/stocks.csv', usecols=[0, 1, 3], index_col=[ 'Date', 'Symbol']).sort_index()
close
# Out:
#                     Close
# Date       Symbol
# 2016-10-03 AAPL    112.52
#            CSCO     31.50
#            MSFT     57.42
# 2016-10-04 AAPL    113.00
#            CSCO     31.35
#            MSFT     57.24
# 2016-10-05 AAPL    113.05
#            CSCO     31.59
#            MSFT     57.64

# %%
volume = pd.read_csv('/content/stocks.csv', usecols=[0, 3, 2], index_col=['Symbol', 'Date']).sort_index()
volume
# Out:
#                      Volume
# Symbol Date
# AAPL   2016-10-03  21701800
#        2016-10-04  29736800
#        2016-10-05  21453100
# CSCO   2016-10-03  14070500
#        2016-10-04  18460400
#        2016-10-05  11808600
# MSFT   2016-10-03  19189500
#        2016-10-04  20085900
#        2016-10-05  16726400

# %%
both = pd.merge(close, volume, left_index=True, right_index=True)
both
# Out:
#                     Close    Volume
# Date       Symbol
# 2016-10-03 AAPL    112.52  21701800
#            CSCO     31.50  14070500
#            MSFT     57.42  19189500
# 2016-10-04 AAPL    113.00  29736800
#            CSCO     31.35  18460400
#            MSFT     57.24  20085900
# 2016-10-05 AAPL    113.05  21453100
#            CSCO     31.59  11808600
#            MSFT     57.64  16726400

# %%
both.reset_index()
# Out:
#   Symbol        Date   Close    Volume
# 0   AAPL  2016-10-03  112.52  21701800
# 1   AAPL  2016-10-04  113.00  29736800
# 2   AAPL  2016-10-05  113.05  21453100
# 3   CSCO  2016-10-03   31.50  14070500
# 4   CSCO  2016-10-04   31.35  18460400
# 5   CSCO  2016-10-05   31.59  11808600
# 6   MSFT  2016-10-03   57.42  19189500
# 7   MSFT  2016-10-04   57.24  20085900
# 8   MSFT  2016-10-05   57.64  16726400

# %% [markdown]
# **32: How do I merge DataFrames in pandas?**

# %%
movie_cols = ['movie_id', 'title']
movies = pd.read_table('/content/u.item', sep='|', header=None, names=movie_cols, usecols=[0, 1])
movies.head()
# Out:
#    movie_id              title
# 0         1   Toy Story (1995)
# 1         2   GoldenEye (1995)
# 2         3  Four Rooms (1995)
# 3         4  Get Shorty (1995)
# 4         5     Copycat (1995)

# %%
rating_cols = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings = pd.read_table("/content/u.data", sep='\t', header=None, names=rating_cols)
ratings.head()
# Out:
#    user_id  movie_id  rating  timestamp
# 0      196       242       3  881250949
# 1      186       302       3  891717742
# 2       22       377       1  878887116
# 3      244        51       2  880606923
# 4      166       346       1  886397596

# %%
movies.shape
# Out:
# (1682, 2)

# %%
ratings.shape
# Out:
# (100000, 4)

# %%
movies.movie_id.nunique()  # all unique values
# Out:
# 1682

# %%
ratings.movie_id.nunique()
# Out:
# 1682

# %%
# merging these 2 dataframes
movie_ratings = pd.merge(movies, ratings)
movie_ratings.head()
# Out:
#    movie_id             title  user_id  rating  timestamp
# 0         1  Toy Story (1995)      308       4  887736532
# 1         1  Toy Story (1995)      287       5  875334088
# 2         1  Toy Story (1995)      148       4  877019411
# 3         1  Toy Story (1995)      280       4  891700426
# 4         1  Toy Story (1995)       66       3  883601324

# %%
movie_ratings.shape
# Out:
# (100000, 5)

# %%
# what if the columns you want to join on don't have the same name?

movies.columns = ['m_id', 'title']
movies.columns
# Out:
# Index(['m_id', 'title'], dtype='object')

# %%
ratings.columns
# Out:
# Index(['user_id', 'movie_id', 'rating', 'timestamp'], dtype='object')

# %%
pd.merge(movies, ratings, left_on='m_id', right_on='movie_id').head()
# Out:
#    m_id             title  user_id  movie_id  rating  timestamp
# 0     1  Toy Story (1995)      308         1       4  887736532
# 1     1  Toy Story (1995)      287         1       5  875334088
# 2     1  Toy Story (1995)      148         1       4  877019411
# 3     1  Toy Story (1995)      280         1       4  891700426
# 4     1  Toy Story (1995)       66         1       3  883601324

# %%
# what if we want to join on one index?
movies = movies.set_index('m_id')
movies.head()
# Out:
#                   title
# m_id
# 1      Toy Story (1995)
# 2      GoldenEye (1995)
# 3     Four Rooms (1995)
# 4     Get Shorty (1995)
# 5        Copycat (1995)

# %%
pd.merge(movies, ratings, left_index=True, right_on='movie_id').head()
# Out:
#       movie_id  movie_id_x             title  user_id  movie_id_y  rating  \
# 24           1           2  GoldenEye (1995)      308           1       4
# 454          1           2  GoldenEye (1995)      287           1       5
# 957          1           2  GoldenEye (1995)      148           1       4
# 971          1           2  GoldenEye (1995)      280           1       4
# 1324         1           2  GoldenEye (1995)       66           1       3
#
#       timestamp
# 24    887736532
# 454   875334088
# 957   877019411
# 971   891700426
# 1324  883601324

# %%
# What if you want to join on two indexes?
ratings = ratings.set_index('movie_id')
ratings.head()
# Out:
#           user_id  rating  timestamp
# movie_id
# 242           196       3  881250949
# 302           186       3  891717742
# 377            22       1  878887116
# 51            244       2  880606923
# 346           166       1  886397596

# %%
pd.merge(movies, ratings, left_index=True, right_index=True).head()
# Out:
#               title  user_id  rating  timestamp
# 1  Toy Story (1995)      308       4  887736532
# 1  Toy Story (1995)      287       5  875334088
# 1  Toy Story (1995)      148       4  877019411
# 1  Toy Story (1995)      280       4  891700426
# 1  Toy Story (1995)       66       3  883601324

# %%
# joins

A = pd.DataFrame({'color': ['green', 'yellow', 'red'], 'num':[1, 2, 3]})
A
# Out:
#     color  num
# 0   green    1
# 1  yellow    2
# 2     red    3

# %%
B = pd.DataFrame({'color': ['green', 'yellow', 'pink'], 'size':['S', 'M', 'L']})
B
# Out:
#     color size
# 0   green    S
# 1  yellow    M
# 2    pink    L

# %%
'''
Inner join
Only include observations found in both A and B:
'''

pd.merge(A, B, how='inner')
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M

# %%
'''
Outer join
Include observations found in either A or B:
'''
pd.merge(A, B, how='outer')
# Out:
#     color  num size
# 0   green  1.0    S
# 1  yellow  2.0    M
# 2     red  3.0  NaN
# 3    pink  NaN    L

# %%
'''Left join
Include all observations found in A:
'''

pd.merge(A, B, how='left')
# Out:
#     color  num size
# 0   green    1    S
# 1  yellow    2    M
# 2     red    3  NaN

# %%
'''
Right join
Include all observations found in B:
'''
pd.merge(A, B, how='right')
# Out:
#     color  num size
# 0   green  1.0    S
# 1  yellow  2.0    M
# 2    pink  NaN    L

# %% [markdown]
# **33: 4 new time-saving tricks in pandas**

# %%
# 2. Create a category column during file reading

# %%
import pandas as pd
df=pd.read_csv("/content/drinks.csv")
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
# data types are automatically detected
df.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
# old way to create a category (after file reading)
df['continent'] = df.continent.astype('category')
df.dtypes
# Out:
# country                           object
# beer_servings                      int64
# spirit_servings                    int64
# wine_servings                      int64
# total_litres_of_pure_alcohol     float64
# continent                       category
# dtype: object

# %%
# new way to create a category (during file reading)
df = pd.read_csv('http://bit.ly/drinksbycountry', dtype={'continent':'category'})
df.dtypes
# Out:
# country                           object
# beer_servings                      int64
# spirit_servings                    int64
# wine_servings                      int64
# total_litres_of_pure_alcohol     float64
# continent                       category
# dtype: object

# %%
# 3. Convert the data type of multiple columns at once
# old way to convert data types (one at a time)
df['beer_servings'] = df.beer_servings.astype('float')
df['spirit_servings'] = df.spirit_servings.astype('float')
df.dtypes
# Out:
# country                           object
# beer_servings                    float64
# spirit_servings                  float64
# wine_servings                      int64
# total_litres_of_pure_alcohol     float64
# continent                       category
# dtype: object

# %%
# new way to convert data types (all at once)

df = pd.read_csv('http://bit.ly/drinksbycountry')
df = df.astype({'beer_servings':'float', 'spirit_servings':'float'})
df.dtypes
# Out:
# country                          object
# beer_servings                   float64
# spirit_servings                 float64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
# 4. Apply multiple aggregations on a Series or DataFrame

# %%
# example of a single aggregation function after a groupby
df.groupby('continent').beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
# multiple aggregation functions can be applied simultaneously
df.groupby('continent').beer_servings.agg(['mean', 'min', 'max'])
# Out:
#                      mean   min    max
# continent
# Africa          61.471698   0.0  376.0
# Asia            37.045455   0.0  247.0
# Europe         193.777778   0.0  361.0
# North America  145.434783   1.0  285.0
# Oceania         89.687500   0.0  306.0
# South America  175.083333  93.0  333.0

# %%
# new: apply the same aggregations to a Series
df.beer_servings.agg(['mean', 'min', 'max'])
# Out:
# mean    106.160622
# min       0.000000
# max     376.000000
# Name: beer_servings, dtype: float64

# %%
# new: apply the same aggregations to a DataFrame
df.agg(['mean', 'min', 'max'])
# Out:
# <ipython-input-13-83fbbc832da2>:2: FutureWarning: ['country', 'continent'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df.agg(['mean', 'min', 'max'])
#           country  beer_servings  spirit_servings  wine_servings  \
# mean          NaN     106.160622        80.994819      49.450777
# min   Afghanistan       0.000000         0.000000       0.000000
# max      Zimbabwe     376.000000       438.000000     370.000000
#
#       total_litres_of_pure_alcohol      continent
# mean                      4.717098            NaN
# min                       0.000000         Africa
# max                      14.400000  South America

# %%
# DataFrame describe method provides similar functionality but is less flexible
df.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %% [markdown]
# **35: Tricks**

# %%
# 4. Reverse row order

# %%
import pandas as pd
df=pd.read_csv("/content/drinks.csv")
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df.loc[::-1].head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 192   Zimbabwe             64               18              4
# 191     Zambia             32               19              4
# 190      Yemen              6                0              0
# 189    Vietnam            111                2              1
# 188  Venezuela            333              100              3
#
#      total_litres_of_pure_alcohol      continent
# 192                           4.7         Africa
# 191                           2.5         Africa
# 190                           0.1           Asia
# 189                           2.0           Asia
# 188                           7.7  South America

# %%
df.loc[::-1].reset_index().head()
# Out:
#    index    country  beer_servings  spirit_servings  wine_servings  \
# 0    192   Zimbabwe             64               18              4
# 1    191     Zambia             32               19              4
# 2    190      Yemen              6                0              0
# 3    189    Vietnam            111                2              1
# 4    188  Venezuela            333              100              3
#
#    total_litres_of_pure_alcohol      continent
# 0                           4.7         Africa
# 1                           2.5         Africa
# 2                           0.1           Asia
# 3                           2.0           Asia
# 4                           7.7  South America

# %%
# 5. Reverse column order

# %%
df.loc[:, ::-1].head()
# Out:
#   continent  total_litres_of_pure_alcohol  wine_servings  spirit_servings  \
# 0      Asia                           0.0              0                0
# 1    Europe                           4.9             54              132
# 2    Africa                           0.7             14                0
# 3    Europe                          12.4            312              138
# 4    Africa                           5.9             45               57
#
#    beer_servings      country
# 0              0  Afghanistan
# 1             89      Albania
# 2             25      Algeria
# 3            245      Andorra
# 4            217       Angola

# %%
# 6. Select columns by data type

# %%
df.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
df.select_dtypes(include='number').head()
# Out:
#    beer_servings  spirit_servings  wine_servings  total_litres_of_pure_alcohol
# 0              0                0              0                           0.0
# 1             89              132             54                           4.9
# 2             25                0             14                           0.7
# 3            245              138            312                          12.4
# 4            217               57             45                           5.9

# %%
df.select_dtypes(include=['number', 'object', 'category', 'datetime']).head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df.select_dtypes(exclude='number').head()
# Out:
#        country continent
# 0  Afghanistan      Asia
# 1      Albania    Europe
# 2      Algeria    Africa
# 3      Andorra    Europe
# 4       Angola    Africa

# %% [markdown]
# **37: Data Science Best Practices**

# %%
import pandas as pd
df=pd.read_csv("/content/ted.csv")
df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# ...

# %%
df.sample(n=3)
# Out:
#       comments                                        description  duration  \
# 526         70  Garik Israelian is a spectroscopist, studying ...       952
# 37         186  In this passionate talk, legendary spacecraft ...      1177
# 1144        15  Singer Inara George and guitarist Mike Andrews...       199
#
#                              event   film_date  languages     main_speaker  \
# 526                 TEDGlobal 2009  1248307200         23  Garik Israelian
# 37                         TED2006  1140739200         28       Burt Rutan
# 1144  TEDxGreatPacificGarbagePatch  1289001600          0     Inara George
#
#                                                    name  num_speaker  \
# 526   Garik Israelian: How spectroscopy could reveal...            1
# 37     Burt Rutan: The real future of space exploration            1
# 1144                        Inara George: "Family Tree"            1
#
#       published_date                                            ratings  \
# ...

# %%
df.shape
# Out:
# (2550, 17)

# %%
df.dtypes
# Out:
# comments               int64
# description           object
# duration               int64
# event                 object
# film_date              int64
# languages              int64
# main_speaker          object
# name                  object
# num_speaker            int64
# published_date         int64
# ratings               object
# related_talks         object
# speaker_occupation    object
# tags                  object
# title                 object
# url                   object
# views                  int64
# dtype: object

# %%
df.isna().sum()
# Out:
# comments              0
# description           0
# duration              0
# event                 0
# film_date             0
# languages             0
# main_speaker          0
# name                  0
# num_speaker           0
# published_date        0
# ratings               0
# related_talks         0
# speaker_occupation    6
# tags                  0
# title                 0
# url                   0
# views                 0
# dtype: int64

# %% [markdown]
# #2. Which talks provoke the most online discussion?

# %%
df.sort_values("comments",ascending=False).head()
# Out:
#       comments                                        description  duration  \
# 96        6404  Richard Dawkins urges all atheists to openly s...      1750
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 644       3356  Questions of good and evil, right and wrong ar...      1386
# 201       2877  Jill Bolte Taylor got a research opportunity f...      1099
# 1787      2673  Our consciousness is a fundamental aspect of o...      1117
#
#         event   film_date  languages       main_speaker  \
# 96    TED2002  1012608000         42    Richard Dawkins
# 0     TED2006  1140825600         60       Ken Robinson
# 644   TED2010  1265846400         39         Sam Harris
# 201   TED2008  1204070400         49  Jill Bolte Taylor
# 1787  TED2014  1395100800         33     David Chalmers
#
#                                                    name  num_speaker  \
# 96                    Richard Dawkins: Militant atheism            1
# ...

# %%
df.sort_values("views",ascending=False).head()
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1346      2290  Body language affects how others see us, but i...      1262
# 677       1930  Simon Sinek has a simple but powerful model fo...      1084
# 837       1927  Brené Brown studies human connection -- our ab...      1219
# 452        354  "Bonk" author Mary Roach delves into obscure s...      1003
#
#                  event   film_date  languages  main_speaker  \
# 0              TED2006  1140825600         60  Ken Robinson
# 1346    TEDGlobal 2012  1340668800         51     Amy Cuddy
# 677   TEDxPuget Sound   1253145600         45   Simon Sinek
# 837        TEDxHouston  1275782400         52   Brené Brown
# 452            TED2009  1233878400         37    Mary Roach
#
#                                                    name  num_speaker  \
# 0             Ken Robinson: Do schools kill creativity?            1
# ...

# %%
# comments or views might not be a good indicator. views per comments is better, make a new column
df['view_per_comment'] = df.views / df.comments

# %%
# sort according to this new column
df.sort_values('view_per_comment').tail().head()
# Out:
#       comments                                        description  duration  \
# 2494         7  Jimmy Lin is developing technologies to catch ...       730
# 2528         3  Digital archaeologist Chance Coughenour is usi...       717
# 2542         3  In the century-old statues that occupy Cape To...       795
# 2501         3  Meet Françoise Mouly, The New Yorker's art dir...       509
# 2534         2  What the astronauts felt when they saw Earth f...       725
#
#                event   film_date  languages        main_speaker  \
# 2494         TED2017  1492992000         10           Jimmy Lin
# 2528     TEDxHamburg  1465344000          5   Chance Coughenour
# 2542  TEDGlobal 2017  1503792000          1  Sethembile Msezane
# 2501          TEDNYC  1488931200         12     Françoise Mouly
# 2534       TEDxSkoll  1491523200          1      Benjamin Grant
#
#                                                    name  num_speaker  \
# ...

# %% [markdown]
# # 3. Visualize the distribution of comments

# %%
# line plot is not appropriate here (use it to measure something over time)
df.comments.plot()
# Out:
# <Axes: >

# %%
# histogram shows the frequency distribution of a single numeric variable
df.comments.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# modify the plot to be more informative
# apply filter first to select rows -> series -> plot
df[df.comments < 1000].comments.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# check how many observations we removed from the plot (outliers)
df[df.comments >= 1000].shape
# Out:
# (32, 18)

# %%
# can also write this using the loc accessor (same as above)
df.loc[df.comments < 1000, 'comments'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# increase the number of bins to see more detail
df.loc[df.comments < 1000, 'comments'].plot(kind='hist', bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # 4. Plot the number of talks that took place each year

# %%
df.columns
# Out:
# Index(['comments', 'description', 'duration', 'event', 'film_date',
#        'languages', 'main_speaker', 'name', 'num_speaker', 'published_date',
#        'ratings', 'related_talks', 'speaker_occupation', 'tags', 'title',
#        'url', 'views', 'comments_per_view', 'view_per_comment'],
#       dtype='object')

# %%
df.film_date.head()
# Out:
# 0    1140825600
# 1    1140825600
# 2    1140739200
# 3    1140912000
# 4    1140566400
# Name: film_date, dtype: int64

# %%
# convert into datetime

pd.to_datetime(df.film_date).head()
# Out:
# 0   1970-01-01 00:00:01.140825600
# 1   1970-01-01 00:00:01.140825600
# 2   1970-01-01 00:00:01.140739200
# 3   1970-01-01 00:00:01.140912000
# 4   1970-01-01 00:00:01.140566400
# Name: film_date, dtype: datetime64[ns]

# %%
# now the results look right
pd.to_datetime(df.film_date, unit='s').head()
# Out:
# 0   2006-02-25
# 1   2006-02-25
# 2   2006-02-24
# 3   2006-02-26
# 4   2006-02-22
# Name: film_date, dtype: datetime64[ns]

# %%
# create a new attribute for this

df['film_datetime'] = pd.to_datetime(df.film_date, unit='s')

# %%
df[['event', 'film_datetime']].head()
# Out:
#      event film_datetime
# 0  TED2006    2006-02-25
# 1  TED2006    2006-02-25
# 2  TED2006    2006-02-24
# 3  TED2006    2006-02-26
# 4  TED2006    2006-02-22

# %%
# event column not always shows the data, verify that event name matches film_datetime for a random sample
df[['event', 'film_datetime']].sample(5)
# Out:
#                  event film_datetime
# 2411  TEDxBeaconStreet    2015-11-14
# 570      TEDIndia 2009    2009-11-05
# 2403       TEDMED 2016    2016-11-30
# 2296         TEDSummit    2016-06-26
# 1334    TEDGlobal 2012    2012-06-27

# %%
# new column uses the datetime data type
df.dtypes
# Out:
# comments                       int64
# description                   object
# duration                       int64
# event                         object
# film_date                      int64
# languages                      int64
# main_speaker                  object
# name                          object
# num_speaker                    int64
# published_date                 int64
# ratings                       object
# related_talks                 object
# speaker_occupation            object
# tags                          object
# title                         object
# url                           object
# views                          int64
# comments_per_view            float64
# view_per_comment             float64
# film_datetime         datetime64[ns]
# dtype: object

# %%
# datetime columns have convenient attributes under the dt namespace
df.film_datetime.dt.year.head()
# Out:
# 0    2006
# 1    2006
# 2    2006
# 3    2006
# 4    2006
# Name: film_datetime, dtype: int64

# %%
# count the number of talks each year using value_counts()
a=df.film_datetime.dt.year.value_counts()

# %%
a.head()
# Out:
# 2013    270
# 2011    270
# 2010    267
# 2012    267
# 2016    246
# Name: film_datetime, dtype: int64

# %%
# points are plotted and connected in the order you give them to pandas
a.plot()
# Out:
# <Axes: >

# %%
# need to sort the index before plotting
df.film_datetime.dt.year.value_counts().sort_index().plot()
# Out:
# <Axes: >

# %% [markdown]
# # 5. What were the "best" events in TED history to attend?

# %%
df.columns
# Out:
# Index(['comments', 'description', 'duration', 'event', 'film_date',
#        'languages', 'main_speaker', 'name', 'num_speaker', 'published_date',
#        'ratings', 'related_talks', 'speaker_occupation', 'tags', 'title',
#        'url', 'views', 'view_per_comment'],
#       dtype='object')

# %%
df.event.describe()
# Out:
# count        2550
# unique        355
# top       TED2014
# freq           84
# Name: event, dtype: object

# %%
df.groupby("event").mean().head()
# Out:
# <ipython-input-43-9ab6dc217f6d>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("event").mean().head()
#                              comments     duration     film_date  languages  \
# event
# AORN Congress                    87.0   510.000000  1.237025e+09   0.000000
# Arbejdsglaede Live              258.0  1092.000000  1.241482e+09  22.000000
# BBC TV                          146.0  3955.000000  4.265316e+08   0.000000
# Bowery Poetry Club              177.0   182.000000  1.131805e+09   0.000000
# Business Innovation Factory      88.0  1105.666667  1.255018e+09  16.333333
#
#                              num_speaker  published_date     views  \
# event
# AORN Congress                        1.0    1.263028e+09  149818.0
# ...

# %%
df.groupby("event").view_per_comment.mean().sort_values().tail()
# Out:
# event
# TEDxZurich                 88775.857143
# TED@StateStreet Boston     98668.823529
# TEDGlobal 2017            103668.766667
# TEDxSkoll                 166534.722826
# TEDxHamburg               179735.666667
# Name: view_per_comment, dtype: float64

# %% [markdown]
# # 6. Unpack the ratings data

# %%
import pandas as pd
df=pd.read_csv("/content/ted.csv")
df.head(2)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-1-2635428e9459> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df=pd.read_csv("/content/ted.csv")
#       3 df.head(2)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df.ratings.head() # list of dicts
# Out:
# 0    [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1    [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2    [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3    [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4    [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# Name: ratings, dtype: object

# %%
# two ways to examine the ratings data for the first talk
df.loc[0, 'ratings']
# Out:
# "[{'id': 7, 'name': 'Funny', 'count': 19645}, {'id': 1, 'name': 'Beautiful', 'count': 4573}, {'id': 9, 'name': 'Ingenious', 'count': 6073}, {'id': 3, 'name': 'Courageous', 'count': 3253}, {'id': 11, 'name': 'Longwinded', 'count': 387}, {'id': 2, 'name': 'Confusing', 'count': 242}, {'id': 8, 'name': 'Informative', 'count': 7346}, {'id': 22, 'name': 'Fascinating', 'count': 10581}, {'id': 21, 'name': 'Unconvincing', 'count': 300}, {'id': 24, 'name': 'Persuasive', 'count': 10704}, {'id': 23, 'name': 'Jaw-dropping', 'count': 4439}, {'id': 25, 'name': 'OK', 'count': 1174}, {'id': 26, 'name': 'Obnoxious', 'count': 209}, {'id': 10, 'name': 'Inspiring', 'count': 24924}]"

# %%
df.ratings[0]
# Out:
# "[{'id': 7, 'name': 'Funny', 'count': 19645}, {'id': 1, 'name': 'Beautiful', 'count': 4573}, {'id': 9, 'name': 'Ingenious', 'count': 6073}, {'id': 3, 'name': 'Courageous', 'count': 3253}, {'id': 11, 'name': 'Longwinded', 'count': 387}, {'id': 2, 'name': 'Confusing', 'count': 242}, {'id': 8, 'name': 'Informative', 'count': 7346}, {'id': 22, 'name': 'Fascinating', 'count': 10581}, {'id': 21, 'name': 'Unconvincing', 'count': 300}, {'id': 24, 'name': 'Persuasive', 'count': 10704}, {'id': 23, 'name': 'Jaw-dropping', 'count': 4439}, {'id': 25, 'name': 'OK', 'count': 1174}, {'id': 26, 'name': 'Obnoxious', 'count': 209}, {'id': 10, 'name': 'Inspiring', 'count': 24924}]"

# %%
# this is a string not a list
type(df.ratings[0])
# Out:
# str

# %%
# convert this into something useful using Python's ast module (Abstract Syntax Tree)
import ast

# %%
# literal_eval() allows you to evaluate a string containing a Python literal or container
ast.literal_eval('[1, 2, 3]')
# Out:
# [1, 2, 3]

# %%
# if you have a string representation of something, you can retrieve what it actually represents
type(ast.literal_eval('[1, 2, 3]'))
# Out:
# list

# %%
# unpack the ratings data for the first talk
ast.literal_eval(df.ratings[0])
# Out:
# [{'id': 7, 'name': 'Funny', 'count': 19645},
#  {'id': 1, 'name': 'Beautiful', 'count': 4573},
#  {'id': 9, 'name': 'Ingenious', 'count': 6073},
#  {'id': 3, 'name': 'Courageous', 'count': 3253},
#  {'id': 11, 'name': 'Longwinded', 'count': 387},
#  {'id': 2, 'name': 'Confusing', 'count': 242},
#  {'id': 8, 'name': 'Informative', 'count': 7346},
#  {'id': 22, 'name': 'Fascinating', 'count': 10581},
#  {'id': 21, 'name': 'Unconvincing', 'count': 300},
#  {'id': 24, 'name': 'Persuasive', 'count': 10704},
#  {'id': 23, 'name': 'Jaw-dropping', 'count': 4439},
#  {'id': 25, 'name': 'OK', 'count': 1174},
#  {'id': 26, 'name': 'Obnoxious', 'count': 209},
#  {'id': 10, 'name': 'Inspiring', 'count': 24924}]

# %%
type(ast.literal_eval(df.ratings[0])) # string type is now list
# Out:
# list

# %%
# define a function to convert an element in the ratings Series from string to list
def str_to_list(ratings_str):
    return ast.literal_eval(ratings_str)

# %%
# test the function
str_to_list(df.ratings[0])
# Out:
# [{'id': 7, 'name': 'Funny', 'count': 19645},
#  {'id': 1, 'name': 'Beautiful', 'count': 4573},
#  {'id': 9, 'name': 'Ingenious', 'count': 6073},
#  {'id': 3, 'name': 'Courageous', 'count': 3253},
#  {'id': 11, 'name': 'Longwinded', 'count': 387},
#  {'id': 2, 'name': 'Confusing', 'count': 242},
#  {'id': 8, 'name': 'Informative', 'count': 7346},
#  {'id': 22, 'name': 'Fascinating', 'count': 10581},
#  {'id': 21, 'name': 'Unconvincing', 'count': 300},
#  {'id': 24, 'name': 'Persuasive', 'count': 10704},
#  {'id': 23, 'name': 'Jaw-dropping', 'count': 4439},
#  {'id': 25, 'name': 'OK', 'count': 1174},
#  {'id': 26, 'name': 'Obnoxious', 'count': 209},
#  {'id': 10, 'name': 'Inspiring', 'count': 24924}]

# %%
# Series apply method applies a function to every element in a Series and returns a Series
df.ratings.apply(str_to_list).head()
# Out:
# 0    [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1    [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2    [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3    [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4    [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# Name: ratings, dtype: object

# %%
# update the column: ratings_list; it now has list of dicts
df['ratings_list'] = df.ratings.apply(str_to_list).head()

# %%
# althogh the type remains same

df.dtypes
# Out:
# comments               int64
# description           object
# duration               int64
# event                 object
# film_date              int64
# languages              int64
# main_speaker          object
# name                  object
# num_speaker            int64
# published_date         int64
# ratings               object
# related_talks         object
# speaker_occupation    object
# tags                  object
# title                 object
# url                   object
# views                  int64
# ratings_list          object
# dtype: object

# %%
# check that the new Series looks as expected (we want to create a series of strings as a series of lists)
df.ratings_list[0]
# Out:
# [{'id': 7, 'name': 'Funny', 'count': 19645},
#  {'id': 1, 'name': 'Beautiful', 'count': 4573},
#  {'id': 9, 'name': 'Ingenious', 'count': 6073},
#  {'id': 3, 'name': 'Courageous', 'count': 3253},
#  {'id': 11, 'name': 'Longwinded', 'count': 387},
#  {'id': 2, 'name': 'Confusing', 'count': 242},
#  {'id': 8, 'name': 'Informative', 'count': 7346},
#  {'id': 22, 'name': 'Fascinating', 'count': 10581},
#  {'id': 21, 'name': 'Unconvincing', 'count': 300},
#  {'id': 24, 'name': 'Persuasive', 'count': 10704},
#  {'id': 23, 'name': 'Jaw-dropping', 'count': 4439},
#  {'id': 25, 'name': 'OK', 'count': 1174},
#  {'id': 26, 'name': 'Obnoxious', 'count': 209},
#  {'id': 10, 'name': 'Inspiring', 'count': 24924}]

# %% [markdown]
# # 7. Count the total number of ratings received by each talk

# %%
df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# ...

# %%
# in the ratings column, we have to sum the counts

# %%
# expected result (for each talk) is sum of count
df.ratings_list[0]
# Out:
# [{'id': 7, 'name': 'Funny', 'count': 19645},
#  {'id': 1, 'name': 'Beautiful', 'count': 4573},
#  {'id': 9, 'name': 'Ingenious', 'count': 6073},
#  {'id': 3, 'name': 'Courageous', 'count': 3253},
#  {'id': 11, 'name': 'Longwinded', 'count': 387},
#  {'id': 2, 'name': 'Confusing', 'count': 242},
#  {'id': 8, 'name': 'Informative', 'count': 7346},
#  {'id': 22, 'name': 'Fascinating', 'count': 10581},
#  {'id': 21, 'name': 'Unconvincing', 'count': 300},
#  {'id': 24, 'name': 'Persuasive', 'count': 10704},
#  {'id': 23, 'name': 'Jaw-dropping', 'count': 4439},
#  {'id': 25, 'name': 'OK', 'count': 1174},
#  {'id': 26, 'name': 'Obnoxious', 'count': 209},
#  {'id': 10, 'name': 'Inspiring', 'count': 24924}]

# %%
# start by building a simple function
def get_num_ratings(list_of_dicts):
    return list_of_dicts[0]

# %%
# pass it a list, and it returns the first element in the list, which is a dictionary
get_num_ratings(df.ratings_list[0])
# Out:
# {'id': 7, 'name': 'Funny', 'count': 19645}

# %%
''' old function
#
def get_num_ratings(list_of_dicts):
    return list_of_dicts[0]['count']
'''

# %%
# the above function is not working as ratings_list has some null values
df.ratings_list.isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2545     True
# 2546     True
# 2547     True
# 2548     True
# 2549     True
# Name: ratings_list, Length: 2550, dtype: bool

# %%
# moreover some values are floats, we can check this using:

types=df.ratings_list.apply(type)

# %%
types
# Out:
# 0        <class 'list'>
# 1        <class 'list'>
# 2        <class 'list'>
# 3        <class 'list'>
# 4        <class 'list'>
#              ...
# 2545    <class 'float'>
# 2546    <class 'float'>
# 2547    <class 'float'>
# 2548    <class 'float'>
# 2549    <class 'float'>
# Name: ratings_list, Length: 2550, dtype: object

# %%
# modified function
def get_num_ratings(ratings):
    if isinstance(ratings, list):
        num = sum(d['count'] for d in ratings)
    elif pd.isna(ratings):  # Handle NaN values if needed
        num = 0
    else:
        num = 0  # If it's a float, keep the original value

    return num

# %%
get_num_ratings(df.ratings_list[0])
# Out:
# 93850

# %%
type(get_num_ratings(df.ratings_list[0]))
# Out:
# int

# %%
# check with another record
df.ratings_list[1]
# Out:
# [{'id': 7, 'name': 'Funny', 'count': 544},
#  {'id': 3, 'name': 'Courageous', 'count': 139},
#  {'id': 2, 'name': 'Confusing', 'count': 62},
#  {'id': 1, 'name': 'Beautiful', 'count': 58},
#  {'id': 21, 'name': 'Unconvincing', 'count': 258},
#  {'id': 11, 'name': 'Longwinded', 'count': 113},
#  {'id': 8, 'name': 'Informative', 'count': 443},
#  {'id': 10, 'name': 'Inspiring', 'count': 413},
#  {'id': 22, 'name': 'Fascinating', 'count': 132},
#  {'id': 9, 'name': 'Ingenious', 'count': 56},
#  {'id': 24, 'name': 'Persuasive', 'count': 268},
#  {'id': 23, 'name': 'Jaw-dropping', 'count': 116},
#  {'id': 26, 'name': 'Obnoxious', 'count': 131},
#  {'id': 25, 'name': 'OK', 'count': 203}]

# %%
# looks about right
get_num_ratings(df.ratings_list[1])
# Out:
# 2936

# %%
# apply this to all elements in the series; create a new column: num_ratings

df['num_ratings'] = df['ratings_list'].apply(get_num_ratings)

# %%
df['num_ratings'].head()
# Out:
# 0    93850
# 1     2936
# 2     2824
# 3     3728
# 4    25620
# Name: num_ratings, dtype: int64

# %% [markdown]
# # 8. Which occupations deliver the funniest TED talks on average?

# %%
# a new column: num_ratings is added
df.head(2)
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 1  TED2006  1140825600         43       Al Gore
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
# 1       Al Gore: Averting the climate crisis            1      1151367060
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
#
#                                        related_talks speaker_occupation  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...    Author/educator
# ...

# %% [markdown]
# # Step 1: Count the number of funny ratings

# %%
# write a custom function
def get_funny_ratings(list_of_dicts):
    for d in list_of_dicts:
        if d['name'] == 'Funny':
            return d['count']

# %%
# examine a record
df.ratings_list[3]
# Out:
# [{'id': 3, 'name': 'Courageous', 'count': 760},
#  {'id': 1, 'name': 'Beautiful', 'count': 291},
#  {'id': 2, 'name': 'Confusing', 'count': 32},
#  {'id': 7, 'name': 'Funny', 'count': 59},
#  {'id': 9, 'name': 'Ingenious', 'count': 105},
#  {'id': 21, 'name': 'Unconvincing', 'count': 36},
#  {'id': 11, 'name': 'Longwinded', 'count': 53},
#  {'id': 8, 'name': 'Informative', 'count': 380},
#  {'id': 10, 'name': 'Inspiring', 'count': 1070},
#  {'id': 22, 'name': 'Fascinating', 'count': 132},
#  {'id': 24, 'name': 'Persuasive', 'count': 460},
#  {'id': 23, 'name': 'Jaw-dropping', 'count': 230},
#  {'id': 26, 'name': 'Obnoxious', 'count': 35},
#  {'id': 25, 'name': 'OK', 'count': 85}]

# %%
# check that the function works
get_funny_ratings(df.ratings_list[3])
# Out:
# 59

# %%
# modified function as the above one was having the same error

def get_funny_ratings(ratings_list):
    if isinstance(ratings_list, list):
        for d in ratings_list:
            if d['name'] == 'Funny':
                return d['count']
    elif pd.isna(ratings_list):  # Handle NaN values if needed
        return 0
    else:
        return 0  # If it's a float, keep the original value

# %%
get_funny_ratings(df.ratings_list[3])
# Out:
# 59

# %%
# applying to all
# create a new column: funny_ratings
df['funny_ratings'] = df['ratings_list'].apply(get_funny_ratings)

# %%
df['funny_ratings'].head()
# Out:
# 0    19645
# 1      544
# 2      964
# 3       59
# 4     1390
# Name: funny_ratings, dtype: int64

# %% [markdown]
# # Step 2: Calculate the percentage of ratings that are funny

# %%
# now a new column is added: funny_ratings

df.head(2)
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 1  TED2006  1140825600         43       Al Gore
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
# 1       Al Gore: Averting the climate crisis            1      1151367060
#
#                                              ratings  \
# 0  [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1  [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
#
#                                        related_talks speaker_occupation  \
# 0  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...    Author/educator
# ...

# %%
# now we have two new columns: funny_ratings and num_ratings
df.columns
# Out:
# Index(['comments', 'description', 'duration', 'event', 'film_date',
#        'languages', 'main_speaker', 'name', 'num_speaker', 'published_date',
#        'ratings', 'related_talks', 'speaker_occupation', 'tags', 'title',
#        'url', 'views', 'ratings_list', 'funny_ratings', 'num_ratings'],
#       dtype='object')

# %%
# create a new column: funny_rate i.e. the percentage of funny ratings out of total, this is done using two newly created columns
df['funny_rate'] = df.funny_ratings / df.num_ratings

# %%
# see the new column

df.head(2)
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 1  TED2006  1140825600         43       Al Gore
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
# 1       Al Gore: Averting the climate crisis            1      1151367060
#
#    ...                                      related_talks speaker_occupation  \
# 0  ...  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...    Author/educator
# 1  ...  [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...   Climate advocate
#
#                                                 tags  \
# 0  ['children', 'creativity', 'culture', 'dance',...
# ...

# %%
df['funny_rate'].head()
# Out:
# 0    0.209323
# 1    0.185286
# 2    0.341360
# 3    0.015826
# 4    0.054254
# Name: funny_rate, dtype: float64

# %%
df.sort_values('funny_rate').head(2)
# Out:
#    comments                                        description  duration  \
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 3             Majora Carter: Greening the ghetto            1      1151367060
# 4  Hans Rosling: The best stats you've ever seen            1      1151440680
#
#    ...                                      related_talks  \
# 3  ...  [{'id': 1041, 'hero': 'https://pe.tedcdn.com/i...
# 4  ...  [{'id': 2056, 'hero': 'https://pe.tedcdn.com/i...
#
#                      speaker_occupation  \
# 3    Activist for environmental justice
# 4  Global health expert; data visionary
#
# ...

# %%
# lets check that this calculation makes sense by examining the occupations of the funniest talks
# be default sorts in ascending order i.e. least funny at head and most funny at tail

df.sort_values('funny_rate').speaker_occupation.tail(20)
# Out:
# 2530                    Artist
# 2531         Policy researcher
# 2532          Hedge fund chair
# 2533                    Artist
# 2534                    Author
# 2535          Writer, activist
# 2536          Marketing leader
# 2537                    Author
# 2538                 Economist
# 2539                      Chef
# 2540         Border specialist
# 2541                 Physicist
# 2542                    Artist
# 2543       Genomics researcher
# 2544    Historian, philosopher
# 2545                Journalist
# 2546            Astrobiologist
# 2547         Robotics engineer
# 2548       Public intellectual
# 2549             Game designer
# Name: speaker_occupation, dtype: object

# %%
# examine the occupations of the least funny talks
df.sort_values('funny_rate').speaker_occupation.head(20)
# Out:
# 3              Activist for environmental justice
# 4            Global health expert; data visionary
# 1                                Climate advocate
# 0                                 Author/educator
# 2                            Technology columnist
# 5     Life coach; expert in leadership psychology
# 6                     Actor, comedian, playwright
# 7                                       Architect
# 8                Philosopher, cognitive scientist
# 9                                  Pastor, author
# 10          Co-founder, Architecture for Humanity
# 11                                      Filmmaker
# 12                 Epidemiologist, philanthropist
# 13              Human-computer interface designer
# 14                                 Tech visionary
# 15                                      Violinist
# 16                              Pianist, composer
# 17                             inventor, engineer
# 18                            Industrial designer
# ...

# %% [markdown]
# # Step 3: Analyze the funny rate by occupation

# %%
df.head(2)
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
#
#      event   film_date  languages  main_speaker  \
# 0  TED2006  1140825600         60  Ken Robinson
# 1  TED2006  1140825600         43       Al Gore
#
#                                         name  num_speaker  published_date  \
# 0  Ken Robinson: Do schools kill creativity?            1      1151367060
# 1       Al Gore: Averting the climate crisis            1      1151367060
#
#    ...                                      related_talks speaker_occupation  \
# 0  ...  [{'id': 865, 'hero': 'https://pe.tedcdn.com/im...    Author/educator
# 1  ...  [{'id': 243, 'hero': 'https://pe.tedcdn.com/im...   Climate advocate
#
#                                                 tags  \
# 0  ['children', 'creativity', 'culture', 'dance',...
# ...

# %%
df.shape
# Out:
# (2550, 21)

# %%
df.speaker_occupation.nunique()
# Out:
# 1458

# %%
# calculate the mean funny rate for each occupation
df.groupby('speaker_occupation').funny_rate.mean().sort_values().tail()
# Out:
# speaker_occupation
# e-Patient                      NaN
# inventor, engineer             NaN
# medical inventor               NaN
# photographer + visual artist   NaN
# physicist                      NaN
# Name: funny_rate, dtype: float64

# %% [markdown]
# # Additional: Step 4: Focus on occupations that are well-represented in the data

# %%
df.columns
# Out:
# Index(['comments', 'description', 'duration', 'event', 'film_date',
#        'languages', 'main_speaker', 'name', 'num_speaker', 'published_date',
#        'ratings', 'related_talks', 'speaker_occupation', 'tags', 'title',
#        'url', 'views', 'ratings_list', 'funny_ratings', 'num_ratings',
#        'funny_rate'],
#       dtype='object')

# %%
df.speaker_occupation.head()
# Out:
# 0                         Author/educator
# 1                        Climate advocate
# 2                    Technology columnist
# 3      Activist for environmental justice
# 4    Global health expert; data visionary
# Name: speaker_occupation, dtype: object

# %%
# count how many times each occupation appears
df.speaker_occupation.value_counts()
# Out:
# Writer                  45
# Artist                  34
# Designer                34
# Journalist              33
# Entrepreneur            31
#                         ..
# Science author           1
# Pro snowboarder          1
# Artist, urban farmer     1
# Entrepreneur, author     1
#  Robotics engineer       1
# Name: speaker_occupation, Length: 1458, dtype: int64

# %%
# value_counts() outputs a pandas Series, thus we can use pandas to manipulate the output
occupation_counts = df.speaker_occupation.value_counts()
type(occupation_counts)
# Out:
# pandas.core.series.Series

# %%
# show occupations which appear at least 5 times
occupation_counts[occupation_counts >= 5]
# Out:
# Writer                        45
# Artist                        34
# Designer                      34
# Journalist                    33
# Entrepreneur                  31
#                               ..
# Data scientist                 5
# Musician, activist             5
# Social Media Theorist          5
# Environmentalist, futurist     5
# Chef                           5
# Name: speaker_occupation, Length: 68, dtype: int64

# %%
# save the index of this Series
top_occupations = occupation_counts[occupation_counts >= 5].index
top_occupations
# Out:
# Index(['Writer', 'Artist', 'Designer', 'Journalist', 'Entrepreneur',
#        'Architect', 'Inventor', 'Psychologist', 'Photographer', 'Filmmaker',
#        'Economist', 'Author', 'Neuroscientist', 'Educator', 'Roboticist',
#        'Philosopher', 'Biologist', 'Physicist', 'Musician', 'Marine biologist',
#        'Activist', 'Global health expert; data visionary', 'Technologist',
#        'Graphic designer', 'Historian', 'Philanthropist', 'Astronomer',
#        'Behavioral economist', 'Oceanographer', 'Singer/songwriter', 'Poet',
#        'Futurist', 'Engineer', 'Computer scientist', 'Social psychologist',
#        'Novelist', 'Mathematician', 'Astrophysicist', 'Social entrepreneur',
#        'Photojournalist', 'Writer, activist', 'Evolutionary biologist',
#        'Legal activist', 'Climate advocate', 'Techno-illusionist',
#        'Singer-songwriter', 'Comedian', 'Performance poet, multimedia artist',
#        'Reporter', 'Paleontologist', 'Chemist', 'Cartoonist',
# ...

# %% [markdown]
# # Step 5: Re-analyze the funny rate by occupation (for top occupations only)

# %%
# filter DataFrame to include only those occupations
ted_top_occupations = df[df.speaker_occupation.isin(top_occupations)]
ted_top_occupations.shape
# Out:
# (786, 21)

# %%
# redo the previous groupby
# applying group by in this new dataframe
ted_top_occupations.groupby('speaker_occupation').funny_rate.mean().sort_values()
# Out:
# speaker_occupation
# Global health expert; data visionary    0.054254
# Climate advocate                        0.185286
# Activist                                     NaN
# Architect                                    NaN
# Artist                                       NaN
#                                           ...
# Techno-illusionist                           NaN
# Technologist                                 NaN
# Violinist                                    NaN
# Writer                                       NaN
# Writer, activist                             NaN
# Name: funny_rate, Length: 68, dtype: float64
